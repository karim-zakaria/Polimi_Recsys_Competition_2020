# %% [markdown]
# # Collaborative Filtering Script

# %%
import scipy.sparse as sps
import numpy as np
import os
import pandas as pd 

URM_all= sps.load_npz("./Processed Matrices/URM_simple_coo_2020.npz").tocsr()
ICM_all= sps.load_npz("./Processed Matrices/ICM_simple_coo_2020.npz").tocsr()

# %%
from Notebooks_utils.evaluation_function import evaluate_algorithm
from Base.Similarity.Compute_Similarity_Python import Compute_Similarity_Python
from KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from KNN.UserKNNCFRecommender import UserKNNCFRecommender
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_train, URM_valid = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)
# Out:
# Warning: 67 (0.84 %) of 7947 users have no train items
# Warning: 2264 (28.49 %) of 7947 users have no sampled items

# %%
similarity_list=["cosine","adjusted"]
vals=[50,100,200]
feature_weighting=['BM25', 'TF-IDF', 'none']
itemCF=ItemKNNCFRecommender(URM_train)
userCF=UserKNNCFRecommender(URM_train)
rec_list = [userCF,itemCF]
evaluator_validation = EvaluatorHoldout(URM_valid, cutoff_list=[10])
resultDF= pd.DataFrame({"recommender":[],"similarity":[],"shrink":[],"topK":[],"MAP":[],"feature_weighting":[]})

for recommender in rec_list:

    for similarity in similarity_list:

        for shrink in vals:

            for topK in vals:
                
                for fw in feature_weighting:

                    recommender.fit(topK=topK, shrink=shrink, similarity=similarity, feature_weighting=fw)
                    MAP,_=evaluator_validation.evaluateRecommender(recommender)
                    MAP=MAP[10]["MAP"]
                    resultDF=resultDF.append({"recommender":[type(recommender)],"similarity":[similarity],"shrink":[shrink],"topK":[topK],"MAP":[MAP],"feature_weighting":[fw]},ignore_index=True)
                    print(str(type(recommender)),similarity,shrink,topK,MAP,fw)

resultDF.to_csv("CF_results")
# Out:
# ItemKNNCFRecommender: URM Detected 67 (0.84 %) cold users.
# ItemKNNCFRecommender: URM Detected 2459 (9.47 %) cold items.
# UserKNNCFRecommender: URM Detected 67 (0.84 %) cold users.
# UserKNNCFRecommender: URM Detected 2459 (9.47 %) cold items.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3600.26 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.26 sec. Users per second: 1743
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 50 50 0.02896905703124959 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3877.25 column/sec, elapsed time 0.03 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.28 sec. Users per second: 1733
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 50 50 0.042837783308721004 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3647.79 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.21 sec. Users per second: 1768
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 50 50 0.042837783308721004 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3667.68 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.38 sec. Users per second: 1682
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 50 100 0.050799471573354356 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3819.19 column/sec, elapsed time 0.03 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.39 sec. Users per second: 1677
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 50 100 0.053528102017718 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3765.86 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.36 sec. Users per second: 1692
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 50 100 0.053528102017718 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3671.07 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.51 sec. Users per second: 1618
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 50 200 0.05444239694137571 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3575.28 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.58 sec. Users per second: 1587
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 50 200 0.05554610129125383 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3679.65 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.66 sec. Users per second: 1552
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 50 200 0.05554610129125383 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3875.24 column/sec, elapsed time 0.03 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.28 sec. Users per second: 1732
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 100 50 0.05085603295547526 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3572.72 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.42 sec. Users per second: 1661
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 100 50 0.05184697423198006 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3682.64 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.22 sec. Users per second: 1766
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 100 50 0.05184697423198006 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3634.93 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.43 sec. Users per second: 1656
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 100 100 0.052507548271229464 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3644.00 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.33 sec. Users per second: 1707
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 100 100 0.0535623546689287 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3687.20 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.29 sec. Users per second: 1730
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine 100 100 0.0535623546689287 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3775.02 column/sec, elapsed time 0.04 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 3.43 sec. Users per second: 1656
# <class 'KNN.UserKNNCFRecommender.UserKNNCFRecommender'> cosine
column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.66 sec. Users per second: 2136
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 50 100 0.0281700735523907 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2685.44 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.74 sec. Users per second: 2072
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 50 200 0.026548562429123054 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2698.91 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.75 sec. Users per second: 2067
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 50 200 0.027544308312215698 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2696.51 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.81 sec. Users per second: 2023
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 50 200 0.027544308312215698 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2843.34 column/sec, elapsed time 0.15 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.60 sec. Users per second: 2183
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 100 50 0.028403882314977806 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2858.70 column/sec, elapsed time 0.15 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.60 sec. Users per second: 2189
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 100 50 0.029420167430571225 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2821.71 column/sec, elapsed time 0.15 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.60 sec. Users per second: 2186
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 100 50 0.029420167430571225 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2766.17 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.68 sec. Users per second: 2122
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 100 100 0.027976971205711056 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2787.11 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.70 sec. Users per second: 2102
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 100 100 0.029332626248862428 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2783.12 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.66 sec. Users per second: 2133
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 100 100 0.029332626248862428 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2697.10 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.75 sec. Users per second: 2065
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 100 200 0.026975088438344546 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2700.90 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.74 sec. Users per second: 2076
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 100 200 0.02821753950209846 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2686.03 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.73 sec. Users per second: 2079
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 100 200 0.02821753950209846 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2821.36 column/sec, elapsed time 0.15 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.60 sec. Users per second: 2186
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 200 50 0.029016333423509552 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2816.39 column/sec, elapsed time 0.15 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.67 sec. Users per second: 2130
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 200 50 0.029903011564373087 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2816.26 column/sec, elapsed time 0.15 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.58 sec. Users per second: 2200
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 200 50 0.029903011564373087 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2745.89 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.66 sec. Users per second: 2137
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 200 100 0.028298830580452645 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2755.63 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.66 sec. Users per second: 2133
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 200 100 0.029234032518514995 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2791.04 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.67 sec. Users per second: 2126
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 200 100 0.029234032518514995 none
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2767.22 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.78 sec. Users per second: 2043
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 200 200 0.027086987184065537 BM25
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2649.91 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.76 sec. Users per second: 2062
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 200 200 0.028058228839270605 TF-IDF
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 25975 ( 100 % ), 2631.39 column/sec, elapsed time 0.16 min
# EvaluatorHoldout: Processed 5683 ( 100.00% ) in 2.76 sec. Users per second: 2062
# <class 'KNN.ItemKNNCFRecommender.ItemKNNCFRecommender'> adjusted 200 200 0.028058228839270605 none

# %%
resultDF_sorted=resultDF.sort_values(by=['MAP'],ascending=False)
resultDF_sorted.to_csv("CF_results_sorted.csv")

# %%
recommender_full= UserKNNCFRecommender(URM_all)
recommender_full.fit(topK=resultDF_sorted.iloc[0]['topK'][0], shrink=resultDF_sorted.iloc[0]['shrink'][0],  similarity=resultDF_sorted.iloc[0]['similarity'][0],feature_weighting=resultDF_sorted.iloc[0]['feature_weighting'][0])
# Out:
# UserKNNCFRecommender: URM Detected 1079 (4.15 %) cold items.
# Unable to load Cython Compute_Similarity, reverting to Python
# Similarity column 7947 ( 100 % ), 3763.28 column/sec, elapsed time 0.04 min

# %%
rec_df=pd.DataFrame({"user_id":[],"item_list":[]})
target_user_list=list(pd.read_csv("./Data/2020/data_target_users_test.csv").user_id)

for uid in target_user_list:
    rec_list=map(str,recommender_full.recommend(uid)[:10])
    rec_df=rec_df.append({"user_id":uid,"item_list":' '.join(rec_list)},ignore_index=True)

    
rec_df=rec_df.astype({"user_id":'int32',"item_list":'str'})
rec_df=rec_df.set_index('user_id')
rec_df.to_csv("CF_recomm_100_50_cosine.csv")
