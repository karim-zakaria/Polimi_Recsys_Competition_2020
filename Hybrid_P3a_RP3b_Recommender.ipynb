# %%
#import libraries

import scipy.sparse as sps
import numpy as np
import os
import pandas as pd 

URM_all= sps.load_npz("./Processed Matrices/URM_simple_coo_2020.npz").tocsr()
ICM_all= sps.load_npz("./Processed Matrices/ICM_simple_coo_2020.npz").tocsr()

# %%
# %load_ext Cython

# %%
from Notebooks_utils.evaluation_function import evaluate_algorithm
from Base.Similarity.Compute_Similarity_Python import Compute_Similarity_Python
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

np.random.seed(41148)
URM_train, URM_valid = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)
# Out:
# Warning: 82 (1.03 %) of 7947 users have no train items
# Warning: 2290 (28.82 %) of 7947 users have no sampled items

# %%
from GraphBased.RP3betaRecommender import RP3betaRecommender
RP3brecommender= RP3betaRecommender(URM_train)
RP3brecommender.fit(topK=770, alpha=0.414615342821205, beta=0.17823717015919388, normalize_similarity=False)
# Out:
# RP3betaRecommender: URM Detected 82 (1.03 %) cold users.
# RP3betaRecommender: URM Detected 2372 (9.13 %) cold items.

# %%
from GraphBased.P3alphaRecommender import P3alphaRecommender
P3arecommender= P3alphaRecommender(URM_train)
P3arecommender.fit(topK=267, alpha=0.4079116116383131, normalize_similarity=False)
# Out:
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.

# %%
from KNN.ItemKNNSimilarityHybridRecommender import ItemKNNSimilarityHybridRecommender

recommender=ItemKNNSimilarityHybridRecommender(URM_train, RP3brecommender.W_sparse, P3arecommender.W_sparse)
evaluator_validation = EvaluatorHoldout(URM_valid, cutoff_list=[10])
resultDF= pd.DataFrame({"topK":[],"alpha":[],"MAP":[]})
for alpha in range(0,101,5):
    for topK in range(50,1201,50):
        recommender.fit(topK,alpha/100)
        MAP,_=evaluator_validation.evaluateRecommender(recommender)
        MAP=MAP[10]["MAP"]
        resultDF=resultDF.append({"topK":[topK],"alpha":[alpha/100],"MAP":[MAP]},ignore_index=True)
        print(topK,alpha/100, MAP)
# Out:
# ItemKNNSimilarityHybridRecommender: URM Detected 82 (1.03 %) cold users.
# ItemKNNSimilarityHybridRecommender: URM Detected 2372 (9.13 %) cold items.
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.24 sec. Users per second: 1744
# 50 0.0 0.058533824128778035
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.27 sec. Users per second: 1729
# 100 0.0 0.06079158074133204
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.31 sec. Users per second: 1709
# 150 0.0 0.06064857373854543
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.32 sec. Users per second: 1704
# 200 0.0 0.06007728094183866
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.46 sec. Users per second: 1637
# 250 0.0 0.06026125830654245
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.42 sec. Users per second: 1656
# 300 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.38 sec. Users per second: 1675
# 350 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.35 sec. Users per second: 1687
# 400 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.35 sec. Users per second: 1690
# 450 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.44 sec. Users per second: 1643
# 500 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1640
# 550 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1640
# 600 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.44 sec. Users per second: 1645
# 650 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.37 sec. Users per second: 1680
# 700 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.32 sec. Users per second: 1705
# 750 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.32 sec. Users per second: 1702
# 800 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.39 sec. Users per second: 1670
# 850 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.42 sec. Users per second: 1654
# 900 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.39 sec. Users per second: 1668
# 950 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.34 sec. Users per second: 1693
# 1000 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.35 sec. Users per second: 1691
# 1050 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.31 sec. Users per second: 1711
# 1100 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.31 sec. Users per second: 1707
# 1150 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.37 sec. Users per second: 1678
# 1200 0.0 0.06069687873578126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.18 sec. Users per second: 1781
# 50 0.05 0.05918044361434131
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.27 sec. Users per second: 1731
# 100 0.05 0.06140078423653015
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.36 sec. Users per second: 1684
# 150 0.05 0.06145027408923483
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.30 sec. Users per second: 1715
# 200 0.05 0.060921378074010255
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1640
# 250 0.05 0.061476408551950204
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.50 sec. Users per second: 1615
# 300 0.05 0.06142271960932154
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.50 sec. Users per second: 1617
# 350 0.05 0.06111942294251191
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.55 sec. Users per second: 1595
# 400 0.05 0.06121423762972474
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.37 sec. Users per second: 1680
# 450 0.05 0.061157142098879895
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.37 sec. Users per second: 1680
# 500 0.05 0.061262324862968176
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1651
# 550 0.05 0.061485650257588925
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1649
# 600 0.05 0.06111720185000131
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.42 sec. Users per second: 1652
# 650 0.05 0.06146435576174966
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.47 sec. Users per second: 1631
# 700 0.05 0.06135840387851173
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.61 sec. Users per second: 1568
# 750 0.05 0.0612814423591211
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.49 sec. Users per second: 1620
# 800 0.05 0.06142720187872844
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.66 sec. Users per second: 1544
# 850 0.05 0.06143571312994783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.46 sec. Users per second: 1634
# 900 0.05 0.06143571312994783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1641
# 950 0.05 0.06143571312994783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1648
# 1000 0.05 0.06143571312994783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1647
# 1050 0.05 0.06143571312994783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1640
# 1100 0.05 0.06143571312994783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1648
# 1150 0.05 0.06143571312994783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.46 sec. Users per second: 1637
# 1200 0.05 0.06143571312994783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.11 sec. Users per second: 1818
# 50 0.1 0.059356797207258415
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.29 sec. Users per second: 1722
# 100 0.1 0.061431346854731776
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.35 sec. Users per second: 1689
# 150 0.1 0.06172572805826377
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.22 sec. Users per second: 1759
# 200 0.1 0.0613215214558577
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.47 sec. Users per second: 1629
# 250 0.1 0.06167176398086583
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.49 sec. Users per second: 1623
# 300 0.1 0.061621174062302615
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.50 sec. Users per second: 1615
# 350 0.1 0.061606091059565264
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.55 sec. Users per second: 1593
# 400 0.1 0.061588603411234656
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.38 sec. Users per second: 1673
# 450 0.1 0.061636968061830416
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.40 sec. Users per second: 1664
# 500 0.1 0.06168444108537291
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.41 sec. Users per second: 1660
# 550 0.1 0.061769346411398605
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1638
# 600 0.1 0.0615281950729342
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1640
# 650 0.1 0.06167121933427584
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1647
# 700 0.1 0.061673844527499286
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.61 sec. Users per second: 1567
# 750 0.1 0.06171168944862724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.50 sec. Users per second: 1615
# 800 0.1 0.06184720590453689
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.63 sec. Users per second: 1557
# 850 0.1 0.061856044511572415
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.49 sec. Users per second: 1622
# 900 0.1 0.061856044511572415
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.52 sec. Users per second: 1608
# 950 0.1 0.061856044511572415
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.46 sec. Users per second: 1634
# 1000 0.1 0.061856044511572415
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.47 sec. Users per second: 1630
# 1050 0.1 0.061856044511572415
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.52 sec. Users per second: 1606
# 1100 0.1 0.061856044511572415
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.54 sec. Users per second: 1598
# 1150 0.1 0.061856044511572415
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.49 sec. Users per second: 1621
# 1200 0.1 0.061856044511572415
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1801
# 50 0.15 0.05926486901335792
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.23 sec. Users per second: 1751
# 100 0.15 0.06148697059271388
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.38 sec. Users per second: 1674
# 150 0.15 0.0616353346787879
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.40 sec. Users per second: 1665
# 200 0.15 0.06139801574162813
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1648
# 250 0.15 0.061808011809795345
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.49 sec. Users per second: 1621
# 300 0.15 0.061937037184013145
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.36 sec. Users per second: 1684
# 350 0.15 0.0615367388370442
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.59 sec. Users per second: 1576
# 400 0.15 0.06176246066552637
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.68 sec. Users per second: 1538
# 450 0.15 0.06169856309280076
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.67 sec. Users per second: 1543
# 500 0.15 0.06180125553092148
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.58 sec. Users per second: 1579
# 550 0.15 0.06197515918845688
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1639
# 600 0.15 0.061708398019510724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.47 sec. Users per second: 1633
# 650 0.15 0.06178139352297795
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.57 sec. Users per second: 1584
# 700 0.15 0.061605226628654246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.58 sec. Users per second: 1579
# 750 0.15 0.06177528947829865
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.72 sec. Users per second: 1520
# 800 0.15 0.061846202263894916
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.57 sec. Users per second: 1586
# 850 0.15 0.06184947582205623
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.69 sec. Users per second: 1531
# 900 0.15 0.06184947582205623
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.58 sec. Users per second: 1582
# 950 0.15 0.06184947582205623
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.53 sec. Users per second: 1600
# 1000 0.15 0.06184947582205623
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.52 sec. Users per second: 1607
# 1050 0.15 0.06184947582205623
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.57 sec. Users per second: 1583
# 1100 0.15 0.06184947582205623
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.58 sec. Users per second: 1579
# 1150 0.15 0.06184947582205623
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.60 sec. Users per second: 1572
# 1200 0.15 0.06184947582205623
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.32 sec. Users per second: 1702
# 50 0.2 0.05945108083203416
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.38 sec. Users per second: 1672
# 100 0.2 0.06159982698354344
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1651
# 150 0.2 0.061689878504449694
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1639
# 200 0.2 0.061451478151805135
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.61 sec. Users per second: 1566
# 250 0.2 0.06194944229926175
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.52 sec. Users per second: 1609
# 300 0.2 0.06187135290546998
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.58 sec. Users per second: 1579
# 350 0.2 0.06180321123139548
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.69 sec. Users per second: 1535
# 400 0.2 0.06190288331105756
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.97 sec. Users per second: 1426
# 450 0.2 0.06175170363092831
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.53 sec. Users per second: 1601
# 500 0.2 0.06196676813472171
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.52 sec. Users per second: 1607
# 550 0.2 0.06213550973064056
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.55 sec. Users per second: 1596
# 600 0.2 0.06167940637519001
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.65 sec. Users per second: 1551
# 650 0.2 0.06199579220842394
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.67 sec. Users per second: 1541
# 700 0.2 0.06173129430410241
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.60 sec. Users per second: 1572
# 750 0.2 0.06183760098982611
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.62 sec. Users per second: 1564
# 800 0.2 0.06185791124697945
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.61 sec. Users per second: 1565
# 850 0.2 0.061864271302835706
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.61 sec. Users per second: 1569
# 900 0.2 0.061864271302835706
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.52 sec. Users per second: 1607
# 950 0.2 0.061864271302835706
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.61 sec. Users per second: 1568
# 1000 0.2 0.061864271302835706
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.59 sec. Users per second: 1576
# 1050 0.2 0.061864271302835706
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.63 sec. Users per second: 1559
# 1100 0.2 0.061864271302835706
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.62 sec. Users per second: 1563
# 1150 0.2 0.061864271302835706
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.50 sec. Users per second: 1616
# 1200 0.2 0.061864271302835706
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.20 sec. Users per second: 1767
# 50 0.25 0.059525726559553065
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.33 sec. Users per second: 1699
# 100 0.25 0.06168491474919654
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.34 sec. Users per second: 1693
# 150 0.25 0.0617940103895609
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.44 sec. Users per second: 1644
# 200 0.25 0.0617046035313542
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.47 sec. Users per second: 1628
# 250 0.25 0.061892158204786
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.51 sec. Users per second: 1614
# 300 0.25 0.062002689812593464
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.58 sec. Users per second: 1581
# 350 0.25 0.06186736150276891
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.64 sec. Users per second: 1555
# 400 0.25 0.062238691643648175
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.52 sec. Users per second: 1608
# 450 0.25 0.06192009454414544
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.51 sec. Users per second: 1610
# 500 0.25 0.062100695244740364
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.45 sec. Users per second: 1639
# 550 0.25 0.062066261616176656
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.21 sec. Users per second: 1760
# 600 0.25 0.06160632903276869
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1858
# 650 0.25 0.061962416612786626
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.22 sec. Users per second: 1759
# 700 0.25 0.061864607872493246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.36 sec. Users per second: 1684
# 750 0.25 0.06203707809569604
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.53 sec. Users per second: 1602
# 800 0.25 0.061829540019872134
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.12 sec. Users per second: 1813
# 850 0.25 0.061856055840978724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.07 sec. Users per second: 1840
# 900 0.25 0.061856055840978724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.04 sec. Users per second: 1860
# 950 0.25 0.061856055840978724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1851
# 1000 0.25 0.061856055840978724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.13 sec. Users per second: 1810
# 1050 0.25 0.061856055840978724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.16 sec. Users per second: 1791
# 1100 0.25 0.061856055840978724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.28 sec. Users per second: 1727
# 1150 0.25 0.061856055840978724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.31 sec. Users per second: 1711
# 1200 0.25 0.061856055840978724
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1933
# 50 0.3 0.059233232551166574
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1858
# 100 0.3 0.06193619864093435
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1894
# 150 0.3 0.061859798803997654
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.03 sec. Users per second: 1865
# 200 0.3 0.06159102492567351
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.10 sec. Users per second: 1827
# 250 0.3 0.061847337765463785
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.21 sec. Users per second: 1764
# 300 0.3 0.06192130100064434
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.31 sec. Users per second: 1708
# 350 0.3 0.062081259077721496
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.28 sec. Users per second: 1723
# 400 0.3 0.06233582123196861
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1855
# 450 0.3 0.06201177858516636
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.02 sec. Users per second: 1871
# 500 0.3 0.062159446817440095
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.21 sec. Users per second: 1760
# 550 0.3 0.06224775419435222
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.98 sec. Users per second: 1898
# 600 0.3 0.061748942429157426
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1935
# 650 0.3 0.06210736509165767
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.10 sec. Users per second: 1826
# 700 0.3 0.06203025075054676
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1929
# 750 0.3 0.062159154925170775
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.22 sec. Users per second: 1757
# 800 0.3 0.06204356725667772
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.25 sec. Users per second: 1740
# 850 0.3 0.06204323990086159
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.76 sec. Users per second: 1506
# 900 0.3 0.06204323990086159
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.29 sec. Users per second: 1722
# 950 0.3 0.06204323990086159
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.26 sec. Users per second: 1736
# 1000 0.3 0.06204323990086159
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.29 sec. Users per second: 1718
# 1050 0.3 0.06204323990086159
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.16 sec. Users per second: 1791
# 1100 0.3 0.06204323990086159
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.07 sec. Users per second: 1845
# 1150 0.3 0.06204323990086159
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.33 sec. Users per second: 1701
# 1200 0.3 0.06204323990086159
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.95 sec. Users per second: 1920
# 50 0.35 0.05913256832728691
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.11 sec. Users per second: 1817
# 100 0.35 0.06190162026320024
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.18 sec. Users per second: 1778
# 150 0.35 0.061871099817112675
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.23 sec. Users per second: 1753
# 200 0.35 0.061741902163545775
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.26 sec. Users per second: 1734
# 250 0.35 0.06212490629718121
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.26 sec. Users per second: 1735
# 300 0.35 0.06218220116433556
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.18 sec. Users per second: 1779
# 350 0.35 0.062128815443382425
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.38 sec. Users per second: 1672
# 400 0.35 0.062436312536262376
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.01 sec. Users per second: 1879
# 450 0.35 0.0622755862586361
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.27 sec. Users per second: 1733
# 500 0.35 0.06234091325725586
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.18 sec. Users per second: 1777
# 550 0.35 0.062391876350314915
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.09 sec. Users per second: 1831
# 600 0.35 0.062128930880845895
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1804
# 650 0.35 0.06228355882025064
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.08 sec. Users per second: 1837
# 700 0.35 0.062173080741799884
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.23 sec. Users per second: 1749
# 750 0.35 0.06210491407065714
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.44 sec. Users per second: 1647
# 800 0.35 0.0622956526134374
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.27 sec. Users per second: 1732
# 850 0.35 0.06232890261133296
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.25 sec. Users per second: 1739
# 900 0.35 0.06232890261133296
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.25 sec. Users per second: 1743
# 950 0.35 0.06232890261133296
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.21 sec. Users per second: 1763
# 1000 0.35 0.06232890261133296
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.29 sec. Users per second: 1718
# 1050 0.35 0.06232890261133296
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.28 sec. Users per second: 1726
# 1100 0.35 0.06232890261133296
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.22 sec. Users per second: 1756
# 1150 0.35 0.06232890261133296
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.47 sec. Users per second: 1629
# 1200 0.35 0.06232890261133296
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.95 sec. Users per second: 1921
# 50 0.4 0.05913763580088786
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.24 sec. Users per second: 1746
# 100 0.4 0.061639819147268786
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1936
# 150 0.4 0.061839495199738866
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.01 sec. Users per second: 1879
# 200 0.4 0.06207974839743736
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.00 sec. Users per second: 1883
# 250 0.4 0.06222120986879341
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.15 sec. Users per second: 1795
# 300 0.4 0.06219862897037503
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1852
# 350 0.4 0.062454774123818696
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.13 sec. Users per second: 1809
# 400 0.4 0.06271768429675922
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.97 sec. Users per second: 1906
# 450 0.4 0.06276351502961808
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.00 sec. Users per second: 1883
# 500 0.4 0.0624379031347904
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1894
# 550 0.4 0.06255222644711643
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.01 sec. Users per second: 1882
# 600 0.4 0.06228365544032182
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.00 sec. Users per second: 1889
# 650 0.4 0.06239636596852586
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.07 sec. Users per second: 1842
# 700 0.4 0.06249983746338348
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.02 sec. Users per second: 1872
# 750 0.4 0.06240119290797658
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.95 sec. Users per second: 1915
# 800 0.4 0.06269078079840351
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.08 sec. Users per second: 1839
# 850 0.4 0.06268961167048875
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.21 sec. Users per second: 1760
# 900 0.4 0.06268961167048875
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.19 sec. Users per second: 1771
# 950 0.4 0.06268961167048875
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.44 sec. Users per second: 1643
# 1000 0.4 0.06268961167048875
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.20 sec. Users per second: 1770
# 1050 0.4 0.06268961167048875
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.29 sec. Users per second: 1719
# 1100 0.4 0.06268961167048875
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.21 sec. Users per second: 1764
# 1150 0.4 0.06268961167048875
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.30 sec. Users per second: 1712
# 1200 0.4 0.06268961167048875
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.82 sec. Users per second: 2009
# 50 0.45 0.05908552676761774
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.19 sec. Users per second: 1772
# 100 0.45 0.06168498300399768
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.39 sec. Users per second: 1671
# 150 0.45 0.06219912838284927
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.12 sec. Users per second: 1811
# 200 0.45 0.062032612750807396
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.00 sec. Users per second: 1888
# 250 0.45 0.06220699962004446
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.08 sec. Users per second: 1838
# 300 0.45 0.062463678452544934
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.18 sec. Users per second: 1781
# 350 0.45 0.062353548579358056
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1647
# 400 0.45 0.06249624918712202
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.03 sec. Users per second: 1868
# 450 0.45 0.06257405709945017
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.19 sec. Users per second: 1774
# 500 0.45 0.06244964031612681
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.22 sec. Users per second: 1758
# 550 0.45 0.06252576691116803
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1849
# 600 0.45 0.06209521601542227
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.11 sec. Users per second: 1819
# 650 0.45 0.062235133291494146
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.15 sec. Users per second: 1798
# 700 0.45 0.06242811191119544
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.37 sec. Users per second: 1677
# 750 0.45 0.06225549546349423
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.54 sec. Users per second: 1599
# 800 0.45 0.062478253413530666
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.22 sec. Users per second: 1755
# 850 0.45 0.06250380119672386
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1799
# 900 0.45 0.06250380119672386
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.27 sec. Users per second: 1728
# 950 0.45 0.06250380119672386
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.03 sec. Users per second: 1864
# 1000 0.45 0.06250380119672386
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.04 sec. Users per second: 1860
# 1050 0.45 0.06250380119672386
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1890
# 1100 0.45 0.06250380119672386
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1847
# 1150 0.45 0.06250380119672386
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.01 sec. Users per second: 1880
# 1200 0.45 0.06250380119672386
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.55 sec. Users per second: 2222
# 50 0.5 0.05906718142477976
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.66 sec. Users per second: 2128
# 100 0.5 0.061609149887899464
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.78 sec. Users per second: 2032
# 150 0.5 0.06212343764982926
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.89 sec. Users per second: 1958
# 200 0.5 0.06180293684820842
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1892
# 250 0.5 0.06231775444777453
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.85 sec. Users per second: 1984
# 300 0.5 0.062182025990003026
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.03 sec. Users per second: 1868
# 350 0.5 0.0625006262071802
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.09 sec. Users per second: 1833
# 400 0.5 0.06257894146535065
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.09 sec. Users per second: 1832
# 450 0.5 0.06247744290168553
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1937
# 500 0.5 0.06250449187295763
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1894
# 550 0.5 0.0625768973565372
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.03 sec. Users per second: 1868
# 600 0.5 0.06249296043029787
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.95 sec. Users per second: 1917
# 650 0.5 0.06238808929447162
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1852
# 700 0.5 0.06266986251122535
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.01 sec. Users per second: 1881
# 750 0.5 0.06240988364816731
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1857
# 800 0.5 0.06263404405064658
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.03 sec. Users per second: 1866
# 850 0.5 0.06265997998430746
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.01 sec. Users per second: 1878
# 900 0.5 0.06265997998430746
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.02 sec. Users per second: 1874
# 950 0.5 0.06265997998430746
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1848
# 1000 0.5 0.06265997998430746
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.98 sec. Users per second: 1900
# 1050 0.5 0.06265997998430746
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.16 sec. Users per second: 1792
# 1100 0.5 0.06265997998430746
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.09 sec. Users per second: 1830
# 1150 0.5 0.06265997998430746
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1854
# 1200 0.5 0.06265997998430746
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.65 sec. Users per second: 2138
# 50 0.55 0.05877094723701214
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.81 sec. Users per second: 2011
# 100 0.55 0.061381955681990515
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.83 sec. Users per second: 1996
# 150 0.55 0.061919434682783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.81 sec. Users per second: 2016
# 200 0.55 0.06213366348280847
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.02 sec. Users per second: 1872
# 250 0.55 0.06231944433866618
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.83 sec. Users per second: 1996
# 300 0.55 0.06208461297167238
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.26 sec. Users per second: 1737
# 350 0.55 0.06257500439926122
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1855
# 400 0.55 0.062478409881816535
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.37 sec. Users per second: 1677
# 450 0.55 0.06262974333010295
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1932
# 500 0.55 0.06267819867162126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.21 sec. Users per second: 1764
# 550 0.55 0.06261705047020544
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.17 sec. Users per second: 1785
# 600 0.55 0.0623578478802464
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.25 sec. Users per second: 1739
# 650 0.55 0.06260472207201714
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.28 sec. Users per second: 1724
# 700 0.55 0.06270144914629837
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.31 sec. Users per second: 1710
# 750 0.55 0.06268953520395587
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.17 sec. Users per second: 1787
# 800 0.55 0.06247375029467593
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.17 sec. Users per second: 1784
# 850 0.55 0.062480274028440246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.04 sec. Users per second: 1859
# 900 0.55 0.062480274028440246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.04 sec. Users per second: 1860
# 950 0.55 0.062480274028440246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1853
# 1000 0.55 0.062480274028440246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.18 sec. Users per second: 1780
# 1050 0.55 0.062480274028440246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.32 sec. Users per second: 1705
# 1100 0.55 0.062480274028440246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.10 sec. Users per second: 1827
# 1150 0.55 0.062480274028440246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.03 sec. Users per second: 1864
# 1200 0.55 0.062480274028440246
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.72 sec. Users per second: 2081
# 50 0.6 0.05865520529930711
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.61 sec. Users per second: 2163
# 100 0.6 0.061096466058123314
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.66 sec. Users per second: 2124
# 150 0.6 0.06191086539271354
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.71 sec. Users per second: 2085
# 200 0.6 0.06179657278391366
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.87 sec. Users per second: 1970
# 250 0.6 0.06210525487144433
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.81 sec. Users per second: 2012
# 300 0.6 0.06191191262512509
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1930
# 350 0.6 0.06257834404098613
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.96 sec. Users per second: 1911
# 400 0.6 0.06224428569802924
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.96 sec. Users per second: 1909
# 450 0.6 0.06251926998383664
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.86 sec. Users per second: 1975
# 500 0.6 0.06255907522627743
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.88 sec. Users per second: 1967
# 550 0.6 0.06260928236679417
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.91 sec. Users per second: 1947
# 600 0.6 0.06245239439178473
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.91 sec. Users per second: 1943
# 650 0.6 0.062260270989153065
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.91 sec. Users per second: 1944
# 700 0.6 0.0625302204812683
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.94 sec. Users per second: 1926
# 750 0.6 0.062400698700905186
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1932
# 800 0.6 0.06229193372888608
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1936
# 850 0.6 0.062317607777894045
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1934
# 900 0.6 0.062317607777894045
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.94 sec. Users per second: 1925
# 950 0.6 0.062317607777894045
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1929
# 1000 0.6 0.062317607777894045
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.94 sec. Users per second: 1927
# 1050 0.6 0.062317607777894045
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1929
# 1100 0.6 0.062317607777894045
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1928
# 1150 0.6 0.062317607777894045
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1936
# 1200 0.6 0.062317607777894045
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.48 sec. Users per second: 2277
# 50 0.65 0.058462833011611495
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.60 sec. Users per second: 2177
# 100 0.65 0.06079045762695176
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.67 sec. Users per second: 2122
# 150 0.65 0.06175559120393575
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.70 sec. Users per second: 2092
# 200 0.65 0.061909478751334
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.88 sec. Users per second: 1963
# 250 0.65 0.061911271776009566
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.80 sec. Users per second: 2022
# 300 0.65 0.06189854943738669
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1934
# 350 0.65 0.062415210696001575
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.94 sec. Users per second: 1923
# 400 0.65 0.062486046291319076
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.98 sec. Users per second: 1901
# 450 0.65 0.06279666470520404
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.86 sec. Users per second: 1975
# 500 0.65 0.06227011668854154
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.90 sec. Users per second: 1952
# 550 0.65 0.06261050221259125
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.90 sec. Users per second: 1954
# 600 0.65 0.062482802740774314
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.91 sec. Users per second: 1947
# 650 0.65 0.06221507821042636
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1939
# 700 0.65 0.06256750873049055
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1851
# 750 0.65 0.06224201475056395
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1928
# 800 0.65 0.06252708078825317
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1857
# 850 0.65 0.06252482203312187
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1929
# 900 0.65 0.06253218753898482
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1930
# 950 0.65 0.06253218753898482
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1933
# 1000 0.65 0.06253218753898482
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1934
# 1050 0.65 0.06253218753898482
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1933
# 1100 0.65 0.06253218753898482
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1937
# 1150 0.65 0.06253218753898482
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1935
# 1200 0.65 0.06253218753898482
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.50 sec. Users per second: 2263
# 50 0.7 0.05855154493461842
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.59 sec. Users per second: 2185
# 100 0.7 0.06106498483941719
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.66 sec. Users per second: 2130
# 150 0.7 0.06159680531677493
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.72 sec. Users per second: 2081
# 200 0.7 0.06182697539860912
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.87 sec. Users per second: 1968
# 250 0.7 0.0622491364932567
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.79 sec. Users per second: 2029
# 300 0.7 0.061897643335416336
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1932
# 350 0.7 0.06225157732614245
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1890
# 400 0.7 0.062492569635374084
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.98 sec. Users per second: 1899
# 450 0.7 0.0626882104985192
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.89 sec. Users per second: 1960
# 500 0.7 0.06221670627672038
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.89 sec. Users per second: 1958
# 550 0.7 0.062334206081754405
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1936
# 600 0.7 0.0621594375200895
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.91 sec. Users per second: 1947
# 650 0.7 0.06234387134573482
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1934
# 700 0.7 0.06262970978726638
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.94 sec. Users per second: 1926
# 750 0.7 0.062363415323049176
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1935
# 800 0.7 0.062294801293460766
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1931
# 850 0.7 0.06232114174538016
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1937
# 900 0.7 0.062313776239517206
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.91 sec. Users per second: 1945
# 950 0.7 0.062313776239517206
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.91 sec. Users per second: 1942
# 1000 0.7 0.062313776239517206
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.91 sec. Users per second: 1942
# 1050 0.7 0.062313776239517206
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.96 sec. Users per second: 1908
# 1100 0.7 0.062313776239517206
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.91 sec. Users per second: 1942
# 1150 0.7 0.062313776239517206
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1800
# 1200 0.7 0.062313776239517206
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.69 sec. Users per second: 2102
# 50 0.75 0.05861911031214012
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.84 sec. Users per second: 1994
# 100 0.75 0.06093875487787994
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.96 sec. Users per second: 1911
# 150 0.75 0.06166307335202055
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.87 sec. Users per second: 1971
# 200 0.75 0.06177296157760207
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.02 sec. Users per second: 1874
# 250 0.75 0.06213772829004057
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.80 sec. Users per second: 2017
# 300 0.75 0.061959987805216346
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.54 sec. Users per second: 1600
# 350 0.75 0.06225845692017494
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.44 sec. Users per second: 1644
# 400 0.75 0.062315837579049176
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.47 sec. Users per second: 1631
# 450 0.75 0.06228897160413216
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.32 sec. Users per second: 1703
# 500 0.75 0.06218078741032287
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.37 sec. Users per second: 1680
# 550 0.75 0.06236273246883783
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.34 sec. Users per second: 1691
# 600 0.75 0.06219608561610564
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.32 sec. Users per second: 1703
# 650 0.75 0.062178867952814215
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.38 sec. Users per second: 1674
# 700 0.75 0.062161669942006316
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.50 sec. Users per second: 1617
# 750 0.75 0.0627211374830738
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.41 sec. Users per second: 1658
# 800 0.75 0.06213906852817655
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.49 sec. Users per second: 1030
# 850 0.75 0.06216293276717248
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.41 sec. Users per second: 1660
# 900 0.75 0.06216293276717248
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.35 sec. Users per second: 1690
# 950 0.75 0.06216293276717248
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.39 sec. Users per second: 1667
# 1000 0.75 0.06216293276717248
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.35 sec. Users per second: 1688
# 1050 0.75 0.06216293276717248
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.49 sec. Users per second: 1621
# 1100 0.75 0.06216293276717248
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.42 sec. Users per second: 1652
# 1150 0.75 0.06216293276717248
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.40 sec. Users per second: 1664
# 1200 0.75 0.06216293276717248
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.96 sec. Users per second: 1911
# 50 0.8 0.058210420772254086
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.09 sec. Users per second: 1829
# 100 0.8 0.06094767930447166
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.11 sec. Users per second: 1817
# 150 0.8 0.061049798452368395
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.17 sec. Users per second: 1785
# 200 0.8 0.06166024807090552
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.34 sec. Users per second: 1696
# 250 0.8 0.062082474664552634
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.29 sec. Users per second: 1721
# 300 0.8 0.062056722924211064
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.47 sec. Users per second: 1632
# 350 0.8 0.06232510559006587
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.52 sec. Users per second: 1607
# 400 0.8 0.06249513002550738
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.48 sec. Users per second: 1625
# 450 0.8 0.062439276386871835
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.40 sec. Users per second: 1666
# 500 0.8 0.06246914860720343
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.36 sec. Users per second: 1684
# 550 0.8 0.06234207514771204
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.50 sec. Users per second: 1617
# 600 0.8 0.062344931327207746
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.38 sec. Users per second: 1675
# 650 0.8 0.06229656013506298
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.52 sec. Users per second: 1608
# 700 0.8 0.0622682595010126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.11 sec. Users per second: 1819
# 750 0.8 0.06245519996474352
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.20 sec. Users per second: 1768
# 800 0.8 0.0626958805343676
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.19 sec. Users per second: 1774
# 850 0.8 0.06269882673671277
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.38 sec. Users per second: 1676
# 900 0.8 0.06270619224257572
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.07 sec. Users per second: 1840
# 950 0.8 0.06270619224257572
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.11 sec. Users per second: 1818
# 1000 0.8 0.06270619224257572
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1800
# 1050 0.8 0.06270619224257572
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.11 sec. Users per second: 1817
# 1100 0.8 0.06270619224257572
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1800
# 1150 0.8 0.06270619224257572
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.01 sec. Users per second: 1876
# 1200 0.8 0.06270619224257572
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.64 sec. Users per second: 2142
# 50 0.85 0.0581098391389107
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.71 sec. Users per second: 2086
# 100 0.85 0.06031612038552446
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.89 sec. Users per second: 1955
# 150 0.85 0.06091542158997554
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.95 sec. Users per second: 1917
# 200 0.85 0.06137334580648067
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1799
# 250 0.85 0.06176223658267597
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1894
# 300 0.85 0.06192910707287644
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1848
# 350 0.85 0.061983600793056086
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.25 sec. Users per second: 1742
# 400 0.85 0.06190894863533368
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1891
# 450 0.85 0.06194054877105051
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.08 sec. Users per second: 1837
# 500 0.85 0.062220907482209306
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.95 sec. Users per second: 1915
# 550 0.85 0.06209062098084437
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.11 sec. Users per second: 1816
# 600 0.85 0.062130517721462684
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1892
# 650 0.85 0.062017864619708464
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.13 sec. Users per second: 1808
# 700 0.85 0.06253027671075366
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.24 sec. Users per second: 1745
# 750 0.85 0.06231269468485043
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1858
# 800 0.85 0.06208808038237651
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.36 sec. Users per second: 1684
# 850 0.85 0.06207659019323032
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.22 sec. Users per second: 1756
# 900 0.85 0.06206922468736737
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.15 sec. Users per second: 1793
# 950 0.85 0.06206922468736737
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.13 sec. Users per second: 1806
# 1000 0.85 0.06206922468736737
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.10 sec. Users per second: 1823
# 1050 0.85 0.06206922468736737
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.08 sec. Users per second: 1836
# 1100 0.85 0.06206922468736737
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.19 sec. Users per second: 1774
# 1150 0.85 0.06206922468736737
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.20 sec. Users per second: 1766
# 1200 0.85 0.06206922468736737
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.60 sec. Users per second: 2179
# 50 0.9 0.05800641674742545
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.83 sec. Users per second: 1999
# 100 0.9 0.060215704044599055
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.83 sec. Users per second: 2000
# 150 0.9 0.061102401080309676
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.90 sec. Users per second: 1951
# 200 0.9 0.06136158243111175
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.00 sec. Users per second: 1886
# 250 0.9 0.06181242329129056
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1893
# 300 0.9 0.06190441954513752
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.25 sec. Users per second: 1741
# 350 0.9 0.06220305077916686
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.19 sec. Users per second: 1775
# 400 0.9 0.0623314067998171
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.21 sec. Users per second: 1765
# 450 0.9 0.06225486789233129
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.01 sec. Users per second: 1880
# 500 0.9 0.062161914456758796
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.99 sec. Users per second: 1889
# 550 0.9 0.06218014761898966
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.21 sec. Users per second: 1762
# 600 0.9 0.06261061868000065
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.20 sec. Users per second: 1766
# 650 0.9 0.062221493048276275
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.02 sec. Users per second: 1874
# 700 0.9 0.06231238570104441
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.12 sec. Users per second: 1812
# 750 0.9 0.062410574213055445
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1849
# 800 0.9 0.06241476946155929
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1853
# 850 0.9 0.062407198189183354
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1852
# 900 0.9 0.0624145636950463
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1847
# 950 0.9 0.0624145636950463
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.12 sec. Users per second: 1816
# 1000 0.9 0.0624145636950463
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.16 sec. Users per second: 1792
# 1050 0.9 0.0624145636950463
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.12 sec. Users per second: 1812
# 1100 0.9 0.0624145636950463
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.04 sec. Users per second: 1860
# 1150 0.9 0.0624145636950463
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.07 sec. Users per second: 1840
# 1200 0.9 0.0624145636950463
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.69 sec. Users per second: 2103
# 50 0.95 0.05769222447652343
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.82 sec. Users per second: 2007
# 100 0.95 0.059981162231618736
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.77 sec. Users per second: 2043
# 150 0.95 0.06129288851111571
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1930
# 200 0.95 0.06133904899371934
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.97 sec. Users per second: 1902
# 250 0.95 0.06195139401913348
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.92 sec. Users per second: 1937
# 300 0.95 0.06219208232727088
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.30 sec. Users per second: 1715
# 350 0.95 0.06227048081621418
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.19 sec. Users per second: 1775
# 400 0.95 0.06228901622584742
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.20 sec. Users per second: 1766
# 450 0.95 0.06242704725321061
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1852
# 500 0.95 0.062189903518219805
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1800
# 550 0.95 0.06238553241172198
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.07 sec. Users per second: 1842
# 600 0.95 0.06208925585698557
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1853
# 650 0.95 0.062392940089698944
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.18 sec. Users per second: 1779
# 700 0.95 0.062428860013878845
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.26 sec. Users per second: 1734
# 750 0.95 0.06253948598701081
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.29 sec. Users per second: 1721
# 800 0.95 0.06237873323698817
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.23 sec. Users per second: 1750
# 850 0.95 0.062352142591695026
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.15 sec. Users per second: 1797
# 900 0.95 0.062352142591695026
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1799
# 950 0.95 0.062352142591695026
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.14 sec. Users per second: 1804
# 1000 0.95 0.062352142591695026
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.05 sec. Users per second: 1856
# 1050 0.95 0.062352142591695026
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.90 sec. Users per second: 1452
# 1100 0.95 0.062352142591695026
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.00 sec. Users per second: 1414
# 1150 0.95 0.062352142591695026
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1652
# 1200 0.95 0.062352142591695026
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.73 sec. Users per second: 2071
# 50 1.0 0.05733094543967285
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.65 sec. Users per second: 2135
# 100 1.0 0.05988366222460395
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.73 sec. Users per second: 2072
# 150 1.0 0.061250251947065515
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.93 sec. Users per second: 1928
# 200 1.0 0.06127106289716672
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.04 sec. Users per second: 1859
# 250 1.0 0.06142328276710345
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1848
# 300 1.0 0.0613620430396737
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.07 sec. Users per second: 1842
# 350 1.0 0.061724127132439126
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.06 sec. Users per second: 1849
# 400 1.0 0.06190963572067456
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.03 sec. Users per second: 1866
# 450 1.0 0.061882249845708344
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 2.96 sec. Users per second: 1911
# 500 1.0 0.061867640924340515
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.16 sec. Users per second: 1790
# 550 1.0 0.061876791465838236
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.26 sec. Users per second: 1738
# 600 1.0 0.061879940094330954
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.23 sec. Users per second: 1752
# 650 1.0 0.061928609664621444
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.15 sec. Users per second: 1362
# 700 1.0 0.06205927674495895
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.30 sec. Users per second: 1715
# 750 1.0 0.062384087759328584
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.56 sec. Users per second: 1587
# 800 1.0 0.06210672852934433
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.36 sec. Users per second: 1296
# 850 1.0 0.06210672852934433
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.43 sec. Users per second: 1649
# 900 1.0 0.06210672852934433
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.54 sec. Users per second: 1600
# 950 1.0 0.06210672852934433
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.23 sec. Users per second: 1081
# 1000 1.0 0.06210672852934433
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.61 sec. Users per second: 1227
# 1050 1.0 0.06210672852934433
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.67 sec. Users per second: 1211
# 1100 1.0 0.06210672852934433
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.59 sec. Users per second: 1013
# 1150 1.0 0.06210672852934433
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.90 sec. Users per second: 1155
# 1200 1.0 0.06210672852934433

# %%
resultDF_sorted=resultDF.sort_values(by=['MAP'],ascending=False)
resultDF_sorted.to_csv("Hybrid_P3a_RP3b_results_sorted.csv")

# %%
RP3brecommender_full= RP3betaRecommender(URM_all)
RP3brecommender_full.fit(topK=770, alpha=0.414615342821205, beta=0.17823717015919388, normalize_similarity=False)

P3arecommender_full= P3alphaRecommender(URM_all)
P3arecommender_full.fit(topK=267, alpha=0.4079116116383131, normalize_similarity=False)

recommender_full= ItemKNNSimilarityHybridRecommender(URM_all, RP3brecommender_full.W_sparse, P3arecommender_full.W_sparse)
recommender_full.fit(topK=resultDF_sorted.iloc[0]['topK'][0], alpha=resultDF_sorted.iloc[0]['alpha'][0])
# Out:
# RP3betaRecommender: URM Detected 1079 (4.15 %) cold items.
# P3alphaRecommender: URM Detected 1079 (4.15 %) cold items.
# ItemKNNSimilarityHybridRecommender: URM Detected 1079 (4.15 %) cold items.

# %%
rec_df=pd.DataFrame({"user_id":[],"item_list":[]})
target_user_list=list(pd.read_csv("./Data/2020/data_target_users_test.csv").user_id)

for uid in target_user_list:
    rec_list=map(str,recommender_full.recommend(uid)[:10])
    rec_df=rec_df.append({"user_id":uid,"item_list":' '.join(rec_list)},ignore_index=True)

    
rec_df=rec_df.astype({"user_id":'int32',"item_list":'str'})
rec_df=rec_df.set_index('user_id')
rec_df.to_csv("Hybrid_P3a_RP3b_recommendations.csv")
