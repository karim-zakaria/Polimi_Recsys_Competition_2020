# %% [markdown]
# # Matrix Factorization Pure SVD

# %%
#import libraries

import scipy.sparse as sps
import numpy as np
import os
import pandas as pd 

URM_all= sps.load_npz("./Processed Matrices/URM_simple_coo_2020.npz").tocsr()
ICM_all= sps.load_npz("./Processed Matrices/ICM_simple_coo_2020.npz").tocsr()
np.random.seed(41148)

# %%
# %load_ext Cython

# %%
from Notebooks_utils.evaluation_function import evaluate_algorithm
from Base.Similarity.Compute_Similarity_Python import Compute_Similarity_Python
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_train, URM_valid = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)
# Out:
# Warning: 82 (1.03 %) of 7947 users have no train items
# Warning: 2290 (28.82 %) of 7947 users have no sampled items

# %%
from MatrixFactorization.PureSVDRecommender import PureSVDRecommender

# %%
from ParameterTuning.run_parameter_search import runParameterSearch_Collaborative as paramSearch

# %%
evaluator_validation = EvaluatorHoldout(URM_valid, cutoff_list=[10])
paramSearch(PureSVDRecommender, URM_train, metric_to_optimize="MAP", evaluator_validation=evaluator_validation, evaluator_validation_earlystopping=evaluator_validation)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 258}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.05 sec. Users per second: 802
# SearchBayesianSkopt: New best config found. Config 0: {'num_factors': 258} - results: ROC_AUC: 0.1029297, PRECISION: 0.0214425, PRECISION_RECALL_MIN_DEN: 0.0645192, RECALL: 0.0617666, MAP: 0.0276657, MRR: 0.0740285, NDCG: 0.0454151, F1: 0.0318337, HIT_RATE: 0.2144246, ARHR: 0.0837107, NOVELTY: 0.0045937, AVERAGE_POPULARITY: 0.1056544, DIVERSITY_MEAN_INTER_LIST: 0.9835803, DIVERSITY_HERFINDAHL: 0.9983406, COVERAGE_ITEM: 0.1649278, COVERAGE_ITEM_CORRECT: 0.0248316, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1196678, DIVERSITY_GINI: 0.0380846, SHANNON_ENTROPY: 10.1875989,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVDRecommender
#
# PureSVDRecommender: Saving model in file 'result_experiments/PureSVDRecommender_best_model'
# PureSVDRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 12.9441
# Function value obtained: -0.0277
# Current minimum: -0.0277
# Iteration No: 2 started. Evaluating function at random point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 160}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.64 sec. Users per second: 1003
# SearchBayesianSkopt: Config 1 is suboptimal. Config: {'num_factors': 160} - results: ROC_AUC: 0.1009466, PRECISION: 0.0215132, PRECISION_RECALL_MIN_DEN: 0.0631393, RECALL: 0.0601713, MAP: 0.0275765, MRR: 0.0724719, NDCG: 0.0447388, F1: 0.0316945, HIT_RATE: 0.2151317, ARHR: 0.0826775, NOVELTY: 0.0044436, AVERAGE_POPULARITY: 0.1368277, DIVERSITY_MEAN_INTER_LIST: 0.9707865, DIVERSITY_HERFINDAHL: 0.9970615, COVERAGE_ITEM: 0.1286237, COVERAGE_ITEM_CORRECT: 0.0199038, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1166478, DIVERSITY_GINI: 0.0247648, SHANNON_ENTROPY: 9.4793493,
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 7.5980
# Function value obtained: -0.0276
# Current minimum: -0.0277
# Iteration No: 3 started. Evaluating function at random point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 232}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.46 sec. Users per second: 876
# SearchBayesianSkopt: New best config found. Config 2: {'num_factors': 232} - results: ROC_AUC: 0.1018217, PRECISION: 0.0210536, PRECISION_RECALL_MIN_DEN: 0.0632007, RECALL: 0.0604333, MAP: 0.0281448, MRR: 0.0741570, NDCG: 0.0453558, F1: 0.0312280, HIT_RATE: 0.2105356, ARHR: 0.0838530, NOVELTY: 0.0045594, AVERAGE_POPULARITY: 0.1121136, DIVERSITY_MEAN_INTER_LIST: 0.9813737, DIVERSITY_HERFINDAHL: 0.9981200, COVERAGE_ITEM: 0.1564581, COVERAGE_ITEM_CORRECT: 0.0227526, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1165220, DIVERSITY_GINI: 0.0347440, SHANNON_ENTROPY: 10.0359869,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVDRecommender
#
# PureSVDRecommender: Saving model in file 'result_experiments/PureSVDRecommender_best_model'
# PureSVDRecommender: Saving complete
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 11.5811
# Function value obtained: -0.0281
# Current minimum: -0.0281
# Iteration No: 4 started. Evaluating function at random point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 21}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.78 sec. Users per second: 978
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'num_factors': 21} - results: ROC_AUC: 0.0749535, PRECISION: 0.0155383, PRECISION_RECALL_MIN_DEN: 0.0431668, RECALL: 0.0403853, MAP: 0.0195824, MRR: 0.0545566, NDCG: 0.0312060, F1: 0.0224420, HIT_RATE: 0.1553827, ARHR: 0.0624310, NOVELTY: 0.0041177, AVERAGE_POPULARITY: 0.2525508, DIVERSITY_MEAN_INTER_LIST: 0.8673529, DIVERSITY_HERFINDAHL: 0.9867200, COVERAGE_ITEM: 0.0407315, COVERAGE_ITEM_CORRECT: 0.0070067, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.0840569, DIVERSITY_GINI: 0.0050021, SHANNON_ENTROPY: 7.1844284,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 6.4161
# Function value obtained: -0.0196
# Current minimum: -0.0281
# Iteration No: 5 started. Evaluating function at random point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 73}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.72 sec. Users per second: 989
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'num_factors': 73} - results: ROC_AUC: 0.0951460, PRECISION: 0.0202404, PRECISION_RECALL_MIN_DEN: 0.0571241, RECALL: 0.0540562, MAP: 0.0251567, MRR: 0.0672350, NDCG: 0.0407646, F1: 0.0294527, HIT_RATE: 0.2024041, ARHR: 0.0776625, NOVELTY: 0.0043124, AVERAGE_POPULARITY: 0.1783106, DIVERSITY_MEAN_INTER_LIST: 0.9450435, DIVERSITY_HERFINDAHL: 0.9944876, COVERAGE_ITEM: 0.0904331, COVERAGE_ITEM_CORRECT: 0.0139365, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1088461, DIVERSITY_GINI: 0.0144342, SHANNON_ENTROPY: 8.6392812,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 7.1054
# Function value obtained: -0.0252
# Current minimum: -0.0281
# Iteration No: 6 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 350}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.89 sec. Users per second: 717
# SearchBayesianSkopt: New best config found. Config 5: {'num_factors': 350} - results: ROC_AUC: 0.1078416, PRECISION: 0.0216899, PRECISION_RECALL_MIN_DEN: 0.0685534, RECALL: 0.0660310, MAP: 0.0300403, MRR: 0.0772307, NDCG: 0.0485635, F1: 0.0326537, HIT_RATE: 0.2168994, ARHR: 0.0863273, NOVELTY: 0.0047108, AVERAGE_POPULARITY: 0.0863696, DIVERSITY_MEAN_INTER_LIST: 0.9892571, DIVERSITY_HERFINDAHL: 0.9989082, COVERAGE_ITEM: 0.1972281, COVERAGE_ITEM_CORRECT: 0.0285274, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1221845, DIVERSITY_GINI: 0.0525575, SHANNON_ENTROPY: 10.7028893,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVDRecommender
#
# PureSVDRecommender: Saving model in file 'result_experiments/PureSVDRecommender_best_model'
# PureSVDRecommender: Saving complete
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 16.8431
# Function value obtained: -0.0300
# Current minimum: -0.0300
# Iteration No: 7 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 320}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.83 sec. Users per second: 722
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'num_factors': 320} - results: ROC_AUC: 0.1074147, PRECISION: 0.0215132, PRECISION_RECALL_MIN_DEN: 0.0663250, RECALL: 0.0636924, MAP: 0.0286270, MRR: 0.0758155, NDCG: 0.0468357, F1: 0.0321628, HIT_RATE: 0.2151317, ARHR: 0.0849822, NOVELTY: 0.0046751, AVERAGE_POPULARITY: 0.0919887, DIVERSITY_MEAN_INTER_LIST: 0.9878179, DIVERSITY_HERFINDAHL: 0.9987643, COVERAGE_ITEM: 0.1873725, COVERAGE_ITEM_CORRECT: 0.0274495, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1216811, DIVERSITY_GINI: 0.0477267, SHANNON_ENTROPY: 10.5508496,
#
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 13.5421
# Function value obtained: -0.0286
# Current minimum: -0.0300
# Iteration No: 8 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 350}
# PureSVDRecommender: Computing SVD decomposition...
# /home/infamouskz/anaconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 8.07 sec. Users per second: 701
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'num_factors': 350} - results: ROC_AUC: 0.1075844, PRECISION: 0.0213187, PRECISION_RECALL_MIN_DEN: 0.0665563, RECALL: 0.0640740, MAP: 0.0298759, MRR: 0.0768221, NDCG: 0.0479415, F1: 0.0319928, HIT_RATE: 0.2131872, ARHR: 0.0858491, NOVELTY: 0.0047116, AVERAGE_POPULARITY: 0.0863633, DIVERSITY_MEAN_INTER_LIST: 0.9893032, DIVERSITY_HERFINDAHL: 0.9989128, COVERAGE_ITEM: 0.1979211, COVERAGE_ITEM_CORRECT: 0.0279115, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1202970, DIVERSITY_GINI: 0.0528771, SHANNON_ENTROPY: 10.7116472,
#
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 13.6920
# Function value obtained: -0.0299
# Current minimum: -0.0300
# Iteration No: 9 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 118}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.07 sec. Users per second: 800
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'num_factors': 118} - results: ROC_AUC: 0.0995900, PRECISION: 0.0217253, PRECISION_RECALL_MIN_DEN: 0.0611876, RECALL: 0.0578166, MAP: 0.0272130, MRR: 0.0737521, NDCG: 0.0438044, F1: 0.0315829, HIT_RATE: 0.2172530, ARHR: 0.0850014, NOVELTY: 0.0043903, AVERAGE_POPULARITY: 0.1524211, DIVERSITY_MEAN_INTER_LIST: 0.9633678, DIVERSITY_HERFINDAHL: 0.9963198, COVERAGE_ITEM: 0.1125698, COVERAGE_ITEM_CORRECT: 0.0174783, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1156411, DIVERSITY_GINI: 0.0201875, SHANNON_ENTROPY: 9.1711802,
#
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 9.6289
# Function value obtained: -0.0272
# Current minimum: -0.0300
# Iteration No: 10 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 93}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.84 sec. Users per second: 827
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'num_factors': 93} - results: ROC_AUC: 0.0964545, PRECISION: 0.0210005, PRECISION_RECALL_MIN_DEN: 0.0606408, RECALL: 0.0574755, MAP: 0.0258714, MRR: 0.0698620, NDCG: 0.0421947, F1: 0.0307614, HIT_RATE: 0.2100053, ARHR: 0.0808372, NOVELTY: 0.0043623, AVERAGE_POPULARITY: 0.1629054, DIVERSITY_MEAN_INTER_LIST: 0.9571639, DIVERSITY_HERFINDAHL: 0.9956995, COVERAGE_ITEM: 0.1011742, COVERAGE_ITEM_CORRECT: 0.0150914, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1117403, DIVERSITY_GINI: 0.0175568, SHANNON_ENTROPY: 8.9648204,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 8.3232
# Function value obtained: -0.0259
# Current minimum: -0.0300
# Iteration No: 11 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 344}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.59 sec. Users per second: 745
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'num_factors': 344} - results: ROC_AUC: 0.1077026, PRECISION: 0.0213187, PRECISION_RECALL_MIN_DEN: 0.0669947, RECALL: 0.0645356, MAP: 0.0297631, MRR: 0.0771973, NDCG: 0.0479746, F1: 0.0320500, HIT_RATE: 0.2131872, ARHR: 0.0863486, NOVELTY: 0.0047047, AVERAGE_POPULARITY: 0.0871625, DIVERSITY_MEAN_INTER_LIST: 0.9890681, DIVERSITY_HERFINDAHL: 0.9988893, COVERAGE_ITEM: 0.1958037, COVERAGE_ITEM_CORRECT: 0.0276805, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1196678, DIVERSITY_GINI: 0.0517670, SHANNON_ENTROPY: 10.6805464,
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 12.9202
# Function value obtained: -0.0298
# Current minimum: -0.0300
# Iteration No: 12 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 196}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.79 sec. Users per second: 833
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'num_factors': 196} - results: ROC_AUC: 0.1018482, PRECISION: 0.0210005, PRECISION_RECALL_MIN_DEN: 0.0630599, RECALL: 0.0603260, MAP: 0.0282254, MRR: 0.0736485, NDCG: 0.0453191, F1: 0.0311554, HIT_RATE: 0.2100053, ARHR: 0.0830126, NOVELTY: 0.0045045, AVERAGE_POPULARITY: 0.1233453, DIVERSITY_MEAN_INTER_LIST: 0.9767682, DIVERSITY_HERFINDAHL: 0.9976596, COVERAGE_ITEM: 0.1435996, COVERAGE_ITEM_CORRECT: 0.0213667, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1153895, DIVERSITY_GINI: 0.0298781, SHANNON_ENTROPY: 9.7773582,
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 10.1933
# Function value obtained: -0.0282
# Current minimum: -0.0300
# Iteration No: 13 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 1}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.15 sec. Users per second: 919
# SearchBayesianSkopt: Config 12 is suboptimal. Config: {'num_factors': 1} - results: ROC_AUC: 0.0245610, PRECISION: 0.0046668, PRECISION_RECALL_MIN_DEN: 0.0127303, RECALL: 0.0116017, MAP: 0.0045621, MRR: 0.0149200, NDCG: 0.0080198, F1: 0.0066561, HIT_RATE: 0.0466678, ARHR: 0.0160656, NOVELTY: 0.0038761, AVERAGE_POPULARITY: 0.3324303, DIVERSITY_MEAN_INTER_LIST: 0.0704385, DIVERSITY_HERFINDAHL: 0.9070426, COVERAGE_ITEM: 0.0025794, COVERAGE_ITEM_CORRECT: 0.0007315, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.0284384, DIVERSITY_GINI: 0.0004589, SHANNON_ENTROPY: 3.5831614,
#
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 6.5826
# Function value obtained: -0.0046
# Current minimum: -0.0300
# Iteration No: 14 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 289}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.68 sec. Users per second: 736
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'num_factors': 289} - results: ROC_AUC: 0.1057903, PRECISION: 0.0217607, PRECISION_RECALL_MIN_DEN: 0.0676595, RECALL: 0.0649774, MAP: 0.0283306, MRR: 0.0749078, NDCG: 0.0468202, F1: 0.0326028, HIT_RATE: 0.2176065, ARHR: 0.0840204, NOVELTY: 0.0046331, AVERAGE_POPULARITY: 0.0986986, DIVERSITY_MEAN_INTER_LIST: 0.9857529, DIVERSITY_HERFINDAHL: 0.9985579, COVERAGE_ITEM: 0.1753224, COVERAGE_ITEM_CORRECT: 0.0259865, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1230653, DIVERSITY_GINI: 0.0425894, SHANNON_ENTROPY: 10.3674250,
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 11.9536
# Function value obtained: -0.0283
# Current minimum: -0.0300
# Iteration No: 15 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 213}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.63 sec. Users per second: 742
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'num_factors': 213} - results: ROC_AUC: 0.1009809, PRECISION: 0.0211596, PRECISION_RECALL_MIN_DEN: 0.0647263, RECALL: 0.0621029, MAP: 0.0284960, MRR: 0.0742104, NDCG: 0.0460280, F1: 0.0315646, HIT_RATE: 0.2115963, ARHR: 0.0837012, NOVELTY: 0.0045310, AVERAGE_POPULARITY: 0.1176999, DIVERSITY_MEAN_INTER_LIST: 0.9789921, DIVERSITY_HERFINDAHL: 0.9978819, COVERAGE_ITEM: 0.1480269, COVERAGE_ITEM_CORRECT: 0.0220212, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1163961, DIVERSITY_GINI: 0.0317848, SHANNON_ENTROPY: 9.8912177,
#
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 13.2478
# Function value obtained: -0.0285
# Current minimum: -0.0300
# Iteration No: 16 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 47}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.84 sec. Users per second: 968
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'num_factors': 47} - results: ROC_AUC: 0.0904954, PRECISION: 0.0194273, PRECISION_RECALL_MIN_DEN: 0.0553066, RECALL: 0.0520573, MAP: 0.0242753, MRR: 0.0648149, NDCG: 0.0390699, F1: 0.0282951, HIT_RATE: 0.1942726, ARHR: 0.0746377, NOVELTY: 0.0042283, AVERAGE_POPULARITY: 0.2026610, DIVERSITY_MEAN_INTER_LIST: 0.9201583, DIVERSITY_HERFINDAHL: 0.9919996, COVERAGE_ITEM: 0.0671415, COVERAGE_ITEM_CORRECT: 0.0113186, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1039386, DIVERSITY_GINI: 0.0094551, SHANNON_ENTROPY: 8.0518590,
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 7.5430
# Function value obtained: -0.0243
# Current minimum: -0.0300
# Iteration No: 17 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 140}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.28 sec. Users per second: 901
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'num_factors': 140} - results: ROC_AUC: 0.0991783, PRECISION: 0.0209121, PRECISION_RECALL_MIN_DEN: 0.0617048, RECALL: 0.0588134, MAP: 0.0269807, MRR: 0.0727574, NDCG: 0.0437237, F1: 0.0308537, HIT_RATE: 0.2091214, ARHR: 0.0828501, NOVELTY: 0.0044134, AVERAGE_POPULARITY: 0.1444341, DIVERSITY_MEAN_INTER_LIST: 0.9671411, DIVERSITY_HERFINDAHL: 0.9966970, COVERAGE_ITEM: 0.1203080, COVERAGE_ITEM_CORRECT: 0.0185178, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1138795, DIVERSITY_GINI: 0.0222631, SHANNON_ENTROPY: 9.3169086,
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 10.8363
# Function value obtained: -0.0270
# Current minimum: -0.0300
# Iteration No: 18 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 350}
# PureSVDRecommender: Computing SVD decomposition...
# /home/infamouskz/anaconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 8.22 sec. Users per second: 688
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'num_factors': 350} - results: ROC_AUC: 0.1073771, PRECISION: 0.0216546, PRECISION_RECALL_MIN_DEN: 0.0679558, RECALL: 0.0653547, MAP: 0.0298094, MRR: 0.0776495, NDCG: 0.0483003, F1: 0.0325305, HIT_RATE: 0.2165459, ARHR: 0.0866349, NOVELTY: 0.0047126, AVERAGE_POPULARITY: 0.0862313, DIVERSITY_MEAN_INTER_LIST: 0.9893261, DIVERSITY_HERFINDAHL: 0.9989151, COVERAGE_ITEM: 0.1994225, COVERAGE_ITEM_CORRECT: 0.0286429, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1216811, DIVERSITY_GINI: 0.0529931, SHANNON_ENTROPY: 10.7141047,
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 13.5613
# Function value obtained: -0.0298
# Current minimum: -0.0300
# Iteration No: 19 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 178}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.19 sec. Users per second: 786
# SearchBayesianSkopt: Config 18 is suboptimal. Config: {'num_factors': 178} - results: ROC_AUC: 0.1028251, PRECISION: 0.0210536, PRECISION_RECALL_MIN_DEN: 0.0627583, RECALL: 0.0600586, MAP: 0.0277072, MRR: 0.0739776, NDCG: 0.0448594, F1: 0.0311778, HIT_RATE: 0.2105356, ARHR: 0.0835502, NOVELTY: 0.0044718, AVERAGE_POPULARITY: 0.1300153, DIVERSITY_MEAN_INTER_LIST: 0.9737135, DIVERSITY_HERFINDAHL: 0.9973541, COVERAGE_ITEM: 0.1351684, COVERAGE_ITEM_CORRECT: 0.0202502, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1166478, DIVERSITY_GINI: 0.0269517, SHANNON_ENTROPY: 9.6166448,
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 9.6354
# Function value obtained: -0.0277
# Current minimum: -0.0300
# Iteration No: 20 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 350}
# PureSVDRecommender: Computing SVD decomposition...
# /home/infamouskz/anaconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.92 sec. Users per second: 714
# SearchBayesianSkopt: New best config found. Config 19: {'num_factors': 350} - results: ROC_AUC: 0.1079053, PRECISION: 0.0211243, PRECISION_RECALL_MIN_DEN: 0.0657323, RECALL: 0.0631740, MAP: 0.0303346, MRR: 0.0787161, NDCG: 0.0481924, F1: 0.0316615, HIT_RATE: 0.2112427, ARHR: 0.0874922, NOVELTY: 0.0047107, AVERAGE_POPULARITY: 0.0864618, DIVERSITY_MEAN_INTER_LIST: 0.9892141, DIVERSITY_HERFINDAHL: 0.9989039, COVERAGE_ITEM: 0.1994225, COVERAGE_ITEM_CORRECT: 0.0276420, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1195420, DIVERSITY_GINI: 0.0528891, SHANNON_ENTROPY: 10.7080645,
#
# SearchBayesianSkopt: Saving model in result_experiments/PureSVDRecommender
#
# PureSVDRecommender: Saving model in file 'result_experiments/PureSVDRecommender_best_model'
# PureSVDRecommender: Saving complete
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 17.9724
# Function value obtained: -0.0303
# Current minimum: -0.0303
# Iteration No: 21 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 304}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 8.16 sec. Users per second: 693
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'num_factors': 304} - results: ROC_AUC: 0.1078637, PRECISION: 0.0219374, PRECISION_RECALL_MIN_DEN: 0.0696068, RECALL: 0.0669819, MAP: 0.0292428, MRR: 0.0762070, NDCG: 0.0480816, F1: 0.0330504, HIT_RATE: 0.2193742, ARHR: 0.0852367, NOVELTY: 0.0046528, AVERAGE_POPULARITY: 0.0957192, DIVERSITY_MEAN_INTER_LIST: 0.9867839, DIVERSITY_HERFINDAHL: 0.9986609, COVERAGE_ITEM: 0.1821367, COVERAGE_ITEM_CORRECT: 0.0269875, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1241978, DIVERSITY_GINI: 0.0452153, SHANNON_ENTROPY: 10.4590073,
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 12.3967
# Function value obtained: -0.0292
# Current minimum: -0.0303
# Iteration No: 22 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 350}
# PureSVDRecommender: Computing SVD decomposition...
# /home/infamouskz/anaconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 8.22 sec. Users per second: 688
# SearchBayesianSkopt: Config 21 is suboptimal. Config: {'num_factors': 350} - results: ROC_AUC: 0.1078834, PRECISION: 0.0216016, PRECISION_RECALL_MIN_DEN: 0.0680757, RECALL: 0.0656304, MAP: 0.0297648, MRR: 0.0775181, NDCG: 0.0483137, F1: 0.0325046, HIT_RATE: 0.2160156, ARHR: 0.0865967, NOVELTY: 0.0047094, AVERAGE_POPULARITY: 0.0865292, DIVERSITY_MEAN_INTER_LIST: 0.9892367, DIVERSITY_HERFINDAHL: 0.9989062, COVERAGE_ITEM: 0.1983061, COVERAGE_ITEM_CORRECT: 0.0279885, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1220586, DIVERSITY_GINI: 0.0527251, SHANNON_ENTROPY: 10.7072213,
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 14.4272
# Function value obtained: -0.0298
# Current minimum: -0.0303
# Iteration No: 23 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 349}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.89 sec. Users per second: 717
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'num_factors': 349} - results: ROC_AUC: 0.1071909, PRECISION: 0.0213364, PRECISION_RECALL_MIN_DEN: 0.0673189, RECALL: 0.0648617, MAP: 0.0297015, MRR: 0.0761245, NDCG: 0.0479145, F1: 0.0321101, HIT_RATE: 0.2133640, ARHR: 0.0849864, NOVELTY: 0.0047080, AVERAGE_POPULARITY: 0.0867854, DIVERSITY_MEAN_INTER_LIST: 0.9892352, DIVERSITY_HERFINDAHL: 0.9989060, COVERAGE_ITEM: 0.1985756, COVERAGE_ITEM_CORRECT: 0.0278345, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1205486, DIVERSITY_GINI: 0.0524853, SHANNON_ENTROPY: 10.6999945,
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 13.4648
# Function value obtained: -0.0297
# Current minimum: -0.0303
# Iteration No: 24 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 333}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.46 sec. Users per second: 758
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'num_factors': 333} - results: ROC_AUC: 0.1065248, PRECISION: 0.0217607, PRECISION_RECALL_MIN_DEN: 0.0675053, RECALL: 0.0648193, MAP: 0.0290502, MRR: 0.0756289, NDCG: 0.0474590, F1: 0.0325828, HIT_RATE: 0.2176065, ARHR: 0.0848261, NOVELTY: 0.0046902, AVERAGE_POPULARITY: 0.0897324, DIVERSITY_MEAN_INTER_LIST: 0.9883719, DIVERSITY_HERFINDAHL: 0.9988197, COVERAGE_ITEM: 0.1939942, COVERAGE_ITEM_CORRECT: 0.0279885, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1216811, DIVERSITY_GINI: 0.0500277, SHANNON_ENTROPY: 10.6181194,
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 13.4128
# Function value obtained: -0.0291
# Current minimum: -0.0303
# Iteration No: 25 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 273}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.62 sec. Users per second: 855
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'num_factors': 273} - results: ROC_AUC: 0.1054720, PRECISION: 0.0215839, PRECISION_RECALL_MIN_DEN: 0.0664935, RECALL: 0.0637101, MAP: 0.0279983, MRR: 0.0749071, NDCG: 0.0461941, F1: 0.0322440, HIT_RATE: 0.2158388, ARHR: 0.0838162, NOVELTY: 0.0046120, AVERAGE_POPULARITY: 0.1024353, DIVERSITY_MEAN_INTER_LIST: 0.9845834, DIVERSITY_HERFINDAHL: 0.9984409, COVERAGE_ITEM: 0.1704331, COVERAGE_ITEM_CORRECT: 0.0257170, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1231911, DIVERSITY_GINI: 0.0401923, SHANNON_ENTROPY: 10.2713547,
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 11.6844
# Function value obtained: -0.0280
# Current minimum: -0.0303
# Iteration No: 26 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 245}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.44 sec. Users per second: 760
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'num_factors': 245} - results: ROC_AUC: 0.1030228, PRECISION: 0.0209475, PRECISION_RECALL_MIN_DEN: 0.0631971, RECALL: 0.0605952, MAP: 0.0280680, MRR: 0.0743952, NDCG: 0.0453539, F1: 0.0311326, HIT_RATE: 0.2094750, ARHR: 0.0837506, NOVELTY: 0.0045786, AVERAGE_POPULARITY: 0.1086033, DIVERSITY_MEAN_INTER_LIST: 0.9825007, DIVERSITY_HERFINDAHL: 0.9982327, COVERAGE_ITEM: 0.1600385, COVERAGE_ITEM_CORRECT: 0.0234071, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1168995, DIVERSITY_GINI: 0.0362893, SHANNON_ENTROPY: 10.1102469,
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 11.0770
# Function value obtained: -0.0281
# Current minimum: -0.0303
# Iteration No: 27 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 311}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.28 sec. Users per second: 777
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'num_factors': 311} - results: ROC_AUC: 0.1073322, PRECISION: 0.0212657, PRECISION_RECALL_MIN_DEN: 0.0664186, RECALL: 0.0638419, MAP: 0.0284543, MRR: 0.0752330, NDCG: 0.0466625, F1: 0.0319041, HIT_RATE: 0.2126569, ARHR: 0.0840911, NOVELTY: 0.0046635, AVERAGE_POPULARITY: 0.0939420, DIVERSITY_MEAN_INTER_LIST: 0.9873166, DIVERSITY_HERFINDAHL: 0.9987142, COVERAGE_ITEM: 0.1856015, COVERAGE_ITEM_CORRECT: 0.0267180, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1204228, DIVERSITY_GINI: 0.0465152, SHANNON_ENTROPY: 10.5059200,
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 11.7624
# Function value obtained: -0.0285
# Current minimum: -0.0303
# Iteration No: 28 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 106}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.05 sec. Users per second: 935
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'num_factors': 106} - results: ROC_AUC: 0.1000993, PRECISION: 0.0210182, PRECISION_RECALL_MIN_DEN: 0.0598593, RECALL: 0.0567795, MAP: 0.0265284, MRR: 0.0720508, NDCG: 0.0429570, F1: 0.0306797, HIT_RATE: 0.2101821, ARHR: 0.0826636, NOVELTY: 0.0043783, AVERAGE_POPULARITY: 0.1565515, DIVERSITY_MEAN_INTER_LIST: 0.9608626, DIVERSITY_HERFINDAHL: 0.9960693, COVERAGE_ITEM: 0.1077190, COVERAGE_ITEM_CORRECT: 0.0162464, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1141311, DIVERSITY_GINI: 0.0189139, SHANNON_ENTROPY: 9.0775864,
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 7.2291
# Function value obtained: -0.0265
# Current minimum: -0.0303
# Iteration No: 29 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 339}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 8.13 sec. Users per second: 696
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'num_factors': 339} - results: ROC_AUC: 0.1078020, PRECISION: 0.0216016, PRECISION_RECALL_MIN_DEN: 0.0670729, RECALL: 0.0645471, MAP: 0.0296349, MRR: 0.0768280, NDCG: 0.0479391, F1: 0.0323700, HIT_RATE: 0.2160156, ARHR: 0.0858995, NOVELTY: 0.0046959, AVERAGE_POPULARITY: 0.0888405, DIVERSITY_MEAN_INTER_LIST: 0.9886205, DIVERSITY_HERFINDAHL: 0.9988446, COVERAGE_ITEM: 0.1954957, COVERAGE_ITEM_CORRECT: 0.0276420, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1206745, DIVERSITY_GINI: 0.0507911, SHANNON_ENTROPY: 10.6423251,
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 13.0727
# Function value obtained: -0.0296
# Current minimum: -0.0303
# Iteration No: 30 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 60}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.64 sec. Users per second: 852
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'num_factors': 60} - results: ROC_AUC: 0.0916736, PRECISION: 0.0194980, PRECISION_RECALL_MIN_DEN: 0.0565554, RECALL: 0.0536633, MAP: 0.0243954, MRR: 0.0657435, NDCG: 0.0397956, F1: 0.0286033, HIT_RATE: 0.1949797, ARHR: 0.0755839, NOVELTY: 0.0042653, AVERAGE_POPULARITY: 0.1921557, DIVERSITY_MEAN_INTER_LIST: 0.9333200, DIVERSITY_HERFINDAHL: 0.9933155, COVERAGE_ITEM: 0.0771511, COVERAGE_ITEM_CORRECT: 0.0120115, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1054486, DIVERSITY_GINI: 0.0118473, SHANNON_ENTROPY: 8.3654099,
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 10.7567
# Function value obtained: -0.0244
# Current minimum: -0.0303
# Iteration No: 31 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 297}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 7.80 sec. Users per second: 725
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'num_factors': 297} - results: ROC_AUC: 0.1065433, PRECISION: 0.0215662, PRECISION_RECALL_MIN_DEN: 0.0669328, RECALL: 0.0642417, MAP: 0.0287045, MRR: 0.0752518, NDCG: 0.0469241, F1: 0.0322919, HIT_RATE: 0.2156620, ARHR: 0.0844133, NOVELTY: 0.0046407, AVERAGE_POPULARITY: 0.0973672, DIVERSITY_MEAN_INTER_LIST: 0.9861954, DIVERSITY_HERFINDAHL: 0.9986021, COVERAGE_ITEM: 0.1785178, COVERAGE_ITEM_CORRECT: 0.0260635, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1218070, DIVERSITY_GINI: 0.0437039, SHANNON_ENTROPY: 10.4056131,
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 11.0510
# Function value obtained: -0.0287
# Current minimum: -0.0303
# Iteration No: 32 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 34}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.33 sec. Users per second: 1061
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'num_factors': 34} - results: ROC_AUC: 0.0838963, PRECISION: 0.0176595, PRECISION_RECALL_MIN_DEN: 0.0511264, RECALL: 0.0482795, MAP: 0.0225953, MRR: 0.0608618, NDCG: 0.0363443, F1: 0.0258601, HIT_RATE: 0.1765954, ARHR: 0.0696099, NOVELTY: 0.0041897, AVERAGE_POPULARITY: 0.2196775, DIVERSITY_MEAN_INTER_LIST: 0.9056685, DIVERSITY_HERFINDAHL: 0.9905508, COVERAGE_ITEM: 0.0560924, COVERAGE_ITEM_CORRECT: 0.0095091, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.0967661, DIVERSITY_GINI: 0.0074392, SHANNON_ENTROPY: 7.7329005,
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 6.1179
# Function value obtained: -0.0226
# Current minimum: -0.0303
# Iteration No: 33 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 222}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.64 sec. Users per second: 852
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'num_factors': 222} - results: ROC_AUC: 0.1031517, PRECISION: 0.0213718, PRECISION_RECALL_MIN_DEN: 0.0647328, RECALL: 0.0619723, MAP: 0.0288113, MRR: 0.0745577, NDCG: 0.0463232, F1: 0.0317829, HIT_RATE: 0.2137175, ARHR: 0.0843921, NOVELTY: 0.0045479, AVERAGE_POPULARITY: 0.1148007, DIVERSITY_MEAN_INTER_LIST: 0.9803052, DIVERSITY_HERFINDAHL: 0.9980132, COVERAGE_ITEM: 0.1520308, COVERAGE_ITEM_CORRECT: 0.0225987, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1172770, DIVERSITY_GINI: 0.0335051, SHANNON_ENTROPY: 9.9750803,
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 9.9995
# Function value obtained: -0.0288
# Current minimum: -0.0303
# Iteration No: 34 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 129}
# PureSVDRecommender: Computing SVD decomposition...
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.86 sec. Users per second: 824
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'num_factors': 129} - results: ROC_AUC: 0.1012077, PRECISION: 0.0214248, PRECISION_RECALL_MIN_DEN: 0.0611070, RECALL: 0.0579179, MAP: 0.0274082, MRR: 0.0738499, NDCG: 0.0440301, F1: 0.0312790, HIT_RATE: 0.2142478, ARHR: 0.0846421, NOVELTY: 0.0044032, AVERAGE_POPULARITY: 0.1481915, DIVERSITY_MEAN_INTER_LIST: 0.9656997, DIVERSITY_HERFINDAHL: 0.9965529, COVERAGE_ITEM: 0.1163041, COVERAGE_ITEM_CORRECT: 0.0175938, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1152636, DIVERSITY_GINI: 0.0212315, SHANNON_ENTROPY: 9.2503085,
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 10.1343
# Function value obtained: -0.0274
# Current minimum: -0.0303
# Iteration No: 35 started. Searching for the next optimal point.
# PureSVDRecommender: URM Detected 82 (1.03 %) cold users.
# PureSVDRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'num_factors': 350}
# PureSVDRecommender: Computing SVD decomposition...
# /home/infamouskz/anaconda3/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# PureSVDRecommender: Computing SVD decomposition... Done!
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 8.03 sec. Users per second: 704
# SearchBayesianSkopt: Config 34 is suboptimal. Config: {'num_factors': 350} - results: ROC_AUC: 0.1082742, PRECISION: 0.0214955, PRECISION_RECALL_MIN_DEN: 0.0684263, RECALL: 0.0659487, MAP: 0.0300123, MRR: 0.0782711, NDCG: 0.0485786, F1: 0.0324230, HIT_RATE: 0.2149549, ARHR: 0.0870669, NOVELTY: 0.0047099, AVERAGE_POPULARITY: 0.0864368, DIVERSITY_MEAN_INTER_LIST: 0.9892283, DIVERSITY_HERFINDAHL: 0.9989053, COVERAGE_ITEM: 0.1977671, COVERAGE_ITEM_CORRECT: 0.0277575, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1219328, DIVERSITY_GINI: 0.0525677, SHANNON_ENTROPY: 10.7038505,
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 13.5203
# Function value obtained: -0.0300
# Current minimum: -0.0303
# SearchBayesianSkopt: Search complete. Best config is 19: {'num_factors': 350}
