# %% [markdown]
# # Graph Based P3alpha

# %%
#import libraries

import scipy.sparse as sps
import numpy as np
import os
import pandas as pd 

URM_all= sps.load_npz("./Processed Matrices/URM_simple_coo_2020.npz").tocsr()
ICM_all= sps.load_npz("./Processed Matrices/ICM_simple_coo_2020.npz").tocsr()
np.random.seed(41148)

# %%
# %load_ext Cython

# %%
from Notebooks_utils.evaluation_function import evaluate_algorithm
from Base.Similarity.Compute_Similarity_Python import Compute_Similarity_Python
from Base.Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_train, URM_valid = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)
# Out:
# Warning: 82 (1.03 %) of 7947 users have no train items
# Warning: 2290 (28.82 %) of 7947 users have no sampled items

# %%
from GraphBased.P3alphaRecommender import P3alphaRecommender

# %%
from ParameterTuning.run_parameter_search import runParameterSearch_Collaborative as paramSearch

# %%
evaluator_validation = EvaluatorHoldout(URM_valid, cutoff_list=[10])
paramSearch(P3alphaRecommender, URM_train, metric_to_optimize="MAP", evaluator_validation=evaluator_validation, evaluator_validation_earlystopping=evaluator_validation)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 738, 'alpha': 1.0705935086016036, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.11 sec. Users per second: 926
# SearchBayesianSkopt: New best config found. Config 0: {'topK': 738, 'alpha': 1.0705935086016036, 'normalize_similarity': False} - results: ROC_AUC: 0.1349807, PRECISION: 0.0293972, PRECISION_RECALL_MIN_DEN: 0.0999602, RECALL: 0.0964059, MAP: 0.0444371, MRR: 0.0965740, NDCG: 0.0684989, F1: 0.0450556, HIT_RATE: 0.2939721, ARHR: 0.1123419, NOVELTY: 0.0051753, AVERAGE_POPULARITY: 0.0632546, DIVERSITY_MEAN_INTER_LIST: 0.9947201, DIVERSITY_HERFINDAHL: 0.9994544, COVERAGE_ITEM: 0.5010202, COVERAGE_ITEM_CORRECT: 0.0387295, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1540204, DIVERSITY_GINI: 0.2191929, SHANNON_ENTROPY: 12.5231009,
#
# SearchBayesianSkopt: Saving model in result_experiments/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 40.4826
# Function value obtained: -0.0444
# Current minimum: -0.0444
# Iteration No: 2 started. Evaluating function at random point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 481, 'alpha': 0.2579473727414466, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.50 sec. Users per second: 871
# SearchBayesianSkopt: New best config found. Config 1: {'topK': 481, 'alpha': 0.2579473727414466, 'normalize_similarity': True} - results: ROC_AUC: 0.1553531, PRECISION: 0.0343999, PRECISION_RECALL_MIN_DEN: 0.1107278, RECALL: 0.1063952, MAP: 0.0520776, MRR: 0.1176960, NDCG: 0.0791747, F1: 0.0519902, HIT_RATE: 0.3439986, ARHR: 0.1383800, NOVELTY: 0.0050456, AVERAGE_POPULARITY: 0.0748249, DIVERSITY_MEAN_INTER_LIST: 0.9927195, DIVERSITY_HERFINDAHL: 0.9992544, COVERAGE_ITEM: 0.4860443, COVERAGE_ITEM_CORRECT: 0.0423484, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1732729, DIVERSITY_GINI: 0.1851885, SHANNON_ENTROPY: 12.1557011,
#
# SearchBayesianSkopt: Saving model in result_experiments/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 38.6024
# Function value obtained: -0.0521
# Current minimum: -0.0521
# Iteration No: 3 started. Evaluating function at random point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 153, 'alpha': 0.47594988434579777, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.77 sec. Users per second: 1186
# SearchBayesianSkopt: New best config found. Config 2: {'topK': 153, 'alpha': 0.47594988434579777, 'normalize_similarity': False} - results: ROC_AUC: 0.1750277, PRECISION: 0.0372459, PRECISION_RECALL_MIN_DEN: 0.1258549, RECALL: 0.1216356, MAP: 0.0603381, MRR: 0.1311296, NDCG: 0.0904983, F1: 0.0570290, HIT_RATE: 0.3724589, ARHR: 0.1526750, NOVELTY: 0.0049030, AVERAGE_POPULARITY: 0.0982607, DIVERSITY_MEAN_INTER_LIST: 0.9869944, DIVERSITY_HERFINDAHL: 0.9986820, COVERAGE_ITEM: 0.4437344, COVERAGE_ITEM_CORRECT: 0.0428104, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1934063, DIVERSITY_GINI: 0.1459120, SHANNON_ENTROPY: 11.6007161,
#
# SearchBayesianSkopt: Saving model in result_experiments/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 30.5912
# Function value obtained: -0.0603
# Current minimum: -0.0603
# Iteration No: 4 started. Evaluating function at random point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 292, 'alpha': 1.2104543778223802, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.75 sec. Users per second: 1192
# SearchBayesianSkopt: Config 3 is suboptimal. Config: {'topK': 292, 'alpha': 1.2104543778223802, 'normalize_similarity': False} - results: ROC_AUC: 0.1103831, PRECISION: 0.0236698, PRECISION_RECALL_MIN_DEN: 0.0856267, RECALL: 0.0832788, MAP: 0.0358844, MRR: 0.0772078, NDCG: 0.0566720, F1: 0.0368624, HIT_RATE: 0.2366979, ARHR: 0.0871337, NOVELTY: 0.0052825, AVERAGE_POPULARITY: 0.0466004, DIVERSITY_MEAN_INTER_LIST: 0.9966923, DIVERSITY_HERFINDAHL: 0.9996516, COVERAGE_ITEM: 0.5155727, COVERAGE_ITEM_CORRECT: 0.0373436, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1328803, DIVERSITY_GINI: 0.2444566, SHANNON_ENTROPY: 12.8189281,
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 32.4792
# Function value obtained: -0.0359
# Current minimum: -0.0603
# Iteration No: 5 started. Evaluating function at random point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 82, 'alpha': 1.2095828377825704, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.76 sec. Users per second: 1188
# SearchBayesianSkopt: Config 4 is suboptimal. Config: {'topK': 82, 'alpha': 1.2095828377825704, 'normalize_similarity': False} - results: ROC_AUC: 0.0938204, PRECISION: 0.0195687, PRECISION_RECALL_MIN_DEN: 0.0733044, RECALL: 0.0715735, MAP: 0.0315917, MRR: 0.0660062, NDCG: 0.0491268, F1: 0.0307344, HIT_RATE: 0.1956868, ARHR: 0.0734265, NOVELTY: 0.0053834, AVERAGE_POPULARITY: 0.0336389, DIVERSITY_MEAN_INTER_LIST: 0.9975452, DIVERSITY_HERFINDAHL: 0.9997369, COVERAGE_ITEM: 0.5378633, COVERAGE_ITEM_CORRECT: 0.0353417, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1117403, DIVERSITY_GINI: 0.2751260, SHANNON_ENTROPY: 13.0614750,
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 27.4847
# Function value obtained: -0.0316
# Current minimum: -0.0603
# Iteration No: 6 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 742, 'alpha': 0.5817088318626084, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.20 sec. Users per second: 1088
# SearchBayesianSkopt: Config 5 is suboptimal. Config: {'topK': 742, 'alpha': 0.5817088318626084, 'normalize_similarity': False} - results: ROC_AUC: 0.1753136, PRECISION: 0.0374757, PRECISION_RECALL_MIN_DEN: 0.1246620, RECALL: 0.1203869, MAP: 0.0598712, MRR: 0.1318209, NDCG: 0.0900868, F1: 0.0571583, HIT_RATE: 0.3747569, ARHR: 0.1532048, NOVELTY: 0.0048585, AVERAGE_POPULARITY: 0.1073413, DIVERSITY_MEAN_INTER_LIST: 0.9846712, DIVERSITY_HERFINDAHL: 0.9984497, COVERAGE_ITEM: 0.4325698, COVERAGE_ITEM_CORRECT: 0.0400385, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1941613, DIVERSITY_GINI: 0.1366503, SHANNON_ENTROPY: 11.4219183,
#
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 37.6550
# Function value obtained: -0.0599
# Current minimum: -0.0603
# Iteration No: 7 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 997, 'alpha': 2.0, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.48 sec. Users per second: 873
# SearchBayesianSkopt: Config 6 is suboptimal. Config: {'topK': 997, 'alpha': 2.0, 'normalize_similarity': True} - results: ROC_AUC: 0.1064585, PRECISION: 0.0218137, PRECISION_RECALL_MIN_DEN: 0.0819393, RECALL: 0.0795889, MAP: 0.0342663, MRR: 0.0720244, NDCG: 0.0537179, F1: 0.0342423, HIT_RATE: 0.2181368, ARHR: 0.0798614, NOVELTY: 0.0052089, AVERAGE_POPULARITY: 0.0628441, DIVERSITY_MEAN_INTER_LIST: 0.9947947, DIVERSITY_HERFINDAHL: 0.9994619, COVERAGE_ITEM: 0.4594803, COVERAGE_ITEM_CORRECT: 0.0307218, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1270920, DIVERSITY_GINI: 0.2024901, SHANNON_ENTROPY: 12.4888001,
#
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 39.3697
# Function value obtained: -0.0343
# Current minimum: -0.0603
# Iteration No: 8 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 98, 'alpha': 0.6400948262244324, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.55 sec. Users per second: 1244
# SearchBayesianSkopt: Config 7 is suboptimal. Config: {'topK': 98, 'alpha': 0.6400948262244324, 'normalize_similarity': True} - results: ROC_AUC: 0.1547288, PRECISION: 0.0326321, PRECISION_RECALL_MIN_DEN: 0.1082744, RECALL: 0.1042817, MAP: 0.0513811, MRR: 0.1147749, NDCG: 0.0776084, F1: 0.0497091, HIT_RATE: 0.3263214, ARHR: 0.1331891, NOVELTY: 0.0051589, AVERAGE_POPULARITY: 0.0608431, DIVERSITY_MEAN_INTER_LIST: 0.9949055, DIVERSITY_HERFINDAHL: 0.9994730, COVERAGE_ITEM: 0.5113763, COVERAGE_ITEM_CORRECT: 0.0439269, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1697496, DIVERSITY_GINI: 0.2159103, SHANNON_ENTROPY: 12.5058253,
#
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 28.2575
# Function value obtained: -0.0514
# Current minimum: -0.0603
# Iteration No: 9 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 1000, 'alpha': 0.32673538988574286, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.12 sec. Users per second: 925
# SearchBayesianSkopt: Config 8 is suboptimal. Config: {'topK': 1000, 'alpha': 0.32673538988574286, 'normalize_similarity': False} - results: ROC_AUC: 0.1660756, PRECISION: 0.0349655, PRECISION_RECALL_MIN_DEN: 0.1214204, RECALL: 0.1178028, MAP: 0.0569734, MRR: 0.1241345, NDCG: 0.0862656, F1: 0.0539253, HIT_RATE: 0.3496553, ARHR: 0.1420977, NOVELTY: 0.0046782, AVERAGE_POPULARITY: 0.1364762, DIVERSITY_MEAN_INTER_LIST: 0.9736427, DIVERSITY_HERFINDAHL: 0.9973471, COVERAGE_ITEM: 0.3584986, COVERAGE_ITEM_CORRECT: 0.0352647, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1869888, DIVERSITY_GINI: 0.0910969, SHANNON_ENTROPY: 10.6449573,
#
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 39.7119
# Function value obtained: -0.0570
# Current minimum: -0.0603
# Iteration No: 10 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'alpha': 0.0, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.70 sec. Users per second: 1203
# SearchBayesianSkopt: Config 9 is suboptimal. Config: {'topK': 5, 'alpha': 0.0, 'normalize_similarity': False} - results: ROC_AUC: 0.1232887, PRECISION: 0.0234046, PRECISION_RECALL_MIN_DEN: 0.0775448, RECALL: 0.0748361, MAP: 0.0389676, MRR: 0.0910614, NDCG: 0.0584824, F1: 0.0356575, HIT_RATE: 0.2340463, ARHR: 0.1010209, NOVELTY: 0.0050749, AVERAGE_POPULARITY: 0.0798690, DIVERSITY_MEAN_INTER_LIST: 0.9535948, DIVERSITY_HERFINDAHL: 0.9953426, COVERAGE_ITEM: 0.3986141, COVERAGE_ITEM_CORRECT: 0.0247161, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1328803, DIVERSITY_GINI: 0.1149741, SHANNON_ENTROPY: 10.7280700,
#
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 24.7768
# Function value obtained: -0.0390
# Current minimum: -0.0603
# Iteration No: 11 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 999, 'alpha': 1.520410230866848, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.52 sec. Users per second: 1025
# SearchBayesianSkopt: Config 10 is suboptimal. Config: {'topK': 999, 'alpha': 1.520410230866848, 'normalize_similarity': False} - results: ROC_AUC: 0.0961249, PRECISION: 0.0207884, PRECISION_RECALL_MIN_DEN: 0.0794412, RECALL: 0.0777457, MAP: 0.0323286, MRR: 0.0659000, NDCG: 0.0513406, F1: 0.0328051, HIT_RATE: 0.2078840, ARHR: 0.0733504, NOVELTY: 0.0052781, AVERAGE_POPULARITY: 0.0517153, DIVERSITY_MEAN_INTER_LIST: 0.9963384, DIVERSITY_HERFINDAHL: 0.9996162, COVERAGE_ITEM: 0.5095669, COVERAGE_ITEM_CORRECT: 0.0332628, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1194161, DIVERSITY_GINI: 0.2451498, SHANNON_ENTROPY: 12.8003764,
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 40.0846
# Function value obtained: -0.0323
# Current minimum: -0.0603
# Iteration No: 12 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 1000, 'alpha': 0.4980664123376146, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.59 sec. Users per second: 1011
# SearchBayesianSkopt: Config 11 is suboptimal. Config: {'topK': 1000, 'alpha': 0.4980664123376146, 'normalize_similarity': True} - results: ROC_AUC: 0.1551054, PRECISION: 0.0338342, PRECISION_RECALL_MIN_DEN: 0.1091491, RECALL: 0.1048085, MAP: 0.0517206, MRR: 0.1161177, NDCG: 0.0782808, F1: 0.0511547, HIT_RATE: 0.3383419, ARHR: 0.1364236, NOVELTY: 0.0050366, AVERAGE_POPULARITY: 0.0812194, DIVERSITY_MEAN_INTER_LIST: 0.9914677, DIVERSITY_HERFINDAHL: 0.9991292, COVERAGE_ITEM: 0.4863908, COVERAGE_ITEM_CORRECT: 0.0398075, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1720146, DIVERSITY_GINI: 0.1859426, SHANNON_ENTROPY: 12.0986942,
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 39.5135
# Function value obtained: -0.0517
# Current minimum: -0.0603
# Iteration No: 13 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 527, 'alpha': 0.4375864118809543, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.99 sec. Users per second: 1133
# SearchBayesianSkopt: New best config found. Config 12: {'topK': 527, 'alpha': 0.4375864118809543, 'normalize_similarity': False} - results: ROC_AUC: 0.1732786, PRECISION: 0.0370338, PRECISION_RECALL_MIN_DEN: 0.1261264, RECALL: 0.1220540, MAP: 0.0604098, MRR: 0.1301301, NDCG: 0.0905433, F1: 0.0568255, HIT_RATE: 0.3703376, ARHR: 0.1505481, NOVELTY: 0.0047788, AVERAGE_POPULARITY: 0.1182995, DIVERSITY_MEAN_INTER_LIST: 0.9810378, DIVERSITY_HERFINDAHL: 0.9980864, COVERAGE_ITEM: 0.3988450, COVERAGE_ITEM_CORRECT: 0.0393070, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1934063, DIVERSITY_GINI: 0.1143109, SHANNON_ENTROPY: 11.0993517,
#
# SearchBayesianSkopt: Saving model in result_experiments/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 37.1767
# Function value obtained: -0.0604
# Current minimum: -0.0604
# Iteration No: 14 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 976, 'alpha': 0.004909246986992075, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.03 sec. Users per second: 938
# SearchBayesianSkopt: Config 13 is suboptimal. Config: {'topK': 976, 'alpha': 0.004909246986992075, 'normalize_similarity': True} - results: ROC_AUC: 0.1463542, PRECISION: 0.0321902, PRECISION_RECALL_MIN_DEN: 0.1034248, RECALL: 0.0996015, MAP: 0.0464520, MRR: 0.1075736, NDCG: 0.0724003, F1: 0.0486555, HIT_RATE: 0.3219021, ARHR: 0.1257672, NOVELTY: 0.0049998, AVERAGE_POPULARITY: 0.0805714, DIVERSITY_MEAN_INTER_LIST: 0.9915027, DIVERSITY_HERFINDAHL: 0.9991327, COVERAGE_ITEM: 0.4718383, COVERAGE_ITEM_CORRECT: 0.0400000, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1673588, DIVERSITY_GINI: 0.1718205, SHANNON_ENTROPY: 11.9969107,
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 38.9720
# Function value obtained: -0.0465
# Current minimum: -0.0604
# Iteration No: 15 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 355, 'alpha': 0.5804314422395378, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.89 sec. Users per second: 1157
# SearchBayesianSkopt: Config 14 is suboptimal. Config: {'topK': 355, 'alpha': 0.5804314422395378, 'normalize_similarity': False} - results: ROC_AUC: 0.1748580, PRECISION: 0.0375994, PRECISION_RECALL_MIN_DEN: 0.1244209, RECALL: 0.1199729, MAP: 0.0600044, MRR: 0.1318809, NDCG: 0.0900611, F1: 0.0572551, HIT_RATE: 0.3759943, ARHR: 0.1543385, NOVELTY: 0.0049186, AVERAGE_POPULARITY: 0.0960615, DIVERSITY_MEAN_INTER_LIST: 0.9878690, DIVERSITY_HERFINDAHL: 0.9987694, COVERAGE_ITEM: 0.4468527, COVERAGE_ITEM_CORRECT: 0.0423099, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1921480, DIVERSITY_GINI: 0.1495322, SHANNON_ENTROPY: 11.6610780,
#
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 33.7381
# Function value obtained: -0.0600
# Current minimum: -0.0604
# Iteration No: 16 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'alpha': 2.0, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 3.87 sec. Users per second: 1463
# SearchBayesianSkopt: Config 15 is suboptimal. Config: {'topK': 5, 'alpha': 2.0, 'normalize_similarity': False} - results: ROC_AUC: 0.0482879, PRECISION: 0.0086265, PRECISION_RECALL_MIN_DEN: 0.0308991, RECALL: 0.0300921, MAP: 0.0160352, MRR: 0.0328871, NDCG: 0.0232717, F1: 0.0134090, HIT_RATE: 0.0862648, ARHR: 0.0355104, NOVELTY: 0.0056510, AVERAGE_POPULARITY: 0.0164852, DIVERSITY_MEAN_INTER_LIST: 0.8829329, DIVERSITY_HERFINDAHL: 0.9882777, COVERAGE_ITEM: 0.4394225, COVERAGE_ITEM_CORRECT: 0.0177093, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.0533535, DIVERSITY_GINI: 0.1683239, SHANNON_ENTROPY: 10.5856122,
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 23.1338
# Function value obtained: -0.0160
# Current minimum: -0.0604
# Iteration No: 17 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 998, 'alpha': 1.198276656992936, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.99 sec. Users per second: 1133
# SearchBayesianSkopt: Config 16 is suboptimal. Config: {'topK': 998, 'alpha': 1.198276656992936, 'normalize_similarity': True} - results: ROC_AUC: 0.1345515, PRECISION: 0.0295563, PRECISION_RECALL_MIN_DEN: 0.1008472, RECALL: 0.0972329, MAP: 0.0441320, MRR: 0.0953981, NDCG: 0.0684641, F1: 0.0453326, HIT_RATE: 0.2955630, ARHR: 0.1108478, NOVELTY: 0.0051450, AVERAGE_POPULARITY: 0.0712050, DIVERSITY_MEAN_INTER_LIST: 0.9935692, DIVERSITY_HERFINDAHL: 0.9993394, COVERAGE_ITEM: 0.4855823, COVERAGE_ITEM_CORRECT: 0.0373436, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1554046, DIVERSITY_GINI: 0.2080785, SHANNON_ENTROPY: 12.4040358,
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 35.7977
# Function value obtained: -0.0441
# Current minimum: -0.0604
# Iteration No: 18 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 991, 'alpha': 0.8158852532116776, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.77 sec. Users per second: 980
# SearchBayesianSkopt: Config 17 is suboptimal. Config: {'topK': 991, 'alpha': 0.8158852532116776, 'normalize_similarity': True} - results: ROC_AUC: 0.1504976, PRECISION: 0.0326675, PRECISION_RECALL_MIN_DEN: 0.1067695, RECALL: 0.1025995, MAP: 0.0499481, MRR: 0.1103040, NDCG: 0.0757435, F1: 0.0495563, HIT_RATE: 0.3266749, ARHR: 0.1297045, NOVELTY: 0.0050879, AVERAGE_POPULARITY: 0.0769293, DIVERSITY_MEAN_INTER_LIST: 0.9924216, DIVERSITY_HERFINDAHL: 0.9992246, COVERAGE_ITEM: 0.4923195, COVERAGE_ITEM_CORRECT: 0.0391915, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1673588, DIVERSITY_GINI: 0.1988191, SHANNON_ENTROPY: 12.2505813,
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 38.6595
# Function value obtained: -0.0499
# Current minimum: -0.0604
# Iteration No: 19 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 411, 'alpha': 0.5003959427355933, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.41 sec. Users per second: 1282
# SearchBayesianSkopt: New best config found. Config 18: {'topK': 411, 'alpha': 0.5003959427355933, 'normalize_similarity': False} - results: ROC_AUC: 0.1750072, PRECISION: 0.0374580, PRECISION_RECALL_MIN_DEN: 0.1248703, RECALL: 0.1205942, MAP: 0.0605751, MRR: 0.1311579, NDCG: 0.0905394, F1: 0.0571611, HIT_RATE: 0.3745802, ARHR: 0.1526190, NOVELTY: 0.0048430, AVERAGE_POPULARITY: 0.1076310, DIVERSITY_MEAN_INTER_LIST: 0.9844985, DIVERSITY_HERFINDAHL: 0.9984324, COVERAGE_ITEM: 0.4210202, COVERAGE_ITEM_CORRECT: 0.0405775, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1931546, DIVERSITY_GINI: 0.1298161, SHANNON_ENTROPY: 11.3631140,
#
# SearchBayesianSkopt: Saving model in result_experiments/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 33.9246
# Function value obtained: -0.0606
# Current minimum: -0.0606
# Iteration No: 20 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 987, 'alpha': 0.004431700207520929, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.95 sec. Users per second: 1143
# SearchBayesianSkopt: Config 19 is suboptimal. Config: {'topK': 987, 'alpha': 0.004431700207520929, 'normalize_similarity': False} - results: ROC_AUC: 0.1498399, PRECISION: 0.0302457, PRECISION_RECALL_MIN_DEN: 0.1071786, RECALL: 0.1039608, MAP: 0.0502165, MRR: 0.1094497, NDCG: 0.0759118, F1: 0.0468587, HIT_RATE: 0.3024571, ARHR: 0.1243994, NOVELTY: 0.0045989, AVERAGE_POPULARITY: 0.1520523, DIVERSITY_MEAN_INTER_LIST: 0.9650527, DIVERSITY_HERFINDAHL: 0.9964882, COVERAGE_ITEM: 0.3215014, COVERAGE_ITEM_CORRECT: 0.0287199, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1658487, DIVERSITY_GINI: 0.0735168, SHANNON_ENTROPY: 10.2564434,
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 37.1244
# Function value obtained: -0.0502
# Current minimum: -0.0606
# Iteration No: 21 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 625, 'alpha': 0.4997116322211299, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.26 sec. Users per second: 1076
# SearchBayesianSkopt: Config 20 is suboptimal. Config: {'topK': 625, 'alpha': 0.4997116322211299, 'normalize_similarity': False} - results: ROC_AUC: 0.1748128, PRECISION: 0.0373343, PRECISION_RECALL_MIN_DEN: 0.1263175, RECALL: 0.1221158, MAP: 0.0603380, MRR: 0.1320570, NDCG: 0.0907368, F1: 0.0571854, HIT_RATE: 0.3733428, ARHR: 0.1526117, NOVELTY: 0.0048102, AVERAGE_POPULARITY: 0.1138400, DIVERSITY_MEAN_INTER_LIST: 0.9825879, DIVERSITY_HERFINDAHL: 0.9982414, COVERAGE_ITEM: 0.4118576, COVERAGE_ITEM_CORRECT: 0.0398460, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1945388, DIVERSITY_GINI: 0.1228067, SHANNON_ENTROPY: 11.2269343,
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 34.3905
# Function value obtained: -0.0603
# Current minimum: -0.0606
# Iteration No: 22 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 267, 'alpha': 0.4079116116383131, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.75 sec. Users per second: 1190
# SearchBayesianSkopt: New best config found. Config 21: {'topK': 267, 'alpha': 0.4079116116383131, 'normalize_similarity': False} - results: ROC_AUC: 0.1729011, PRECISION: 0.0365565, PRECISION_RECALL_MIN_DEN: 0.1248162, RECALL: 0.1208058, MAP: 0.0606969, MRR: 0.1303643, NDCG: 0.0903197, F1: 0.0561282, HIT_RATE: 0.3655648, ARHR: 0.1511722, NOVELTY: 0.0048055, AVERAGE_POPULARITY: 0.1133893, DIVERSITY_MEAN_INTER_LIST: 0.9825372, DIVERSITY_HERFINDAHL: 0.9982364, COVERAGE_ITEM: 0.4063523, COVERAGE_ITEM_CORRECT: 0.0393070, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1892538, DIVERSITY_GINI: 0.1202948, SHANNON_ENTROPY: 11.2150212,
#
# SearchBayesianSkopt: Saving model in result_experiments/P3alphaRecommender
#
# P3alphaRecommender: Saving model in file 'result_experiments/P3alphaRecommender_best_model'
# P3alphaRecommender: Saving complete
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 32.0021
# Function value obtained: -0.0607
# Current minimum: -0.0607
# Iteration No: 23 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 12, 'alpha': 1.629747458193237, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.48 sec. Users per second: 1264
# SearchBayesianSkopt: Config 22 is suboptimal. Config: {'topK': 12, 'alpha': 1.629747458193237, 'normalize_similarity': True} - results: ROC_AUC: 0.0814088, PRECISION: 0.0151317, PRECISION_RECALL_MIN_DEN: 0.0570193, RECALL: 0.0555243, MAP: 0.0254432, MRR: 0.0542678, NDCG: 0.0392133, F1: 0.0237822, HIT_RATE: 0.1513170, ARHR: 0.0582742, NOVELTY: 0.0054692, AVERAGE_POPULARITY: 0.0292614, DIVERSITY_MEAN_INTER_LIST: 0.9909270, DIVERSITY_HERFINDAHL: 0.9990752, COVERAGE_ITEM: 0.5008277, COVERAGE_ITEM_CORRECT: 0.0274880, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.0931169, DIVERSITY_GINI: 0.2318291, SHANNON_ENTROPY: 12.5996753,
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 22.2456
# Function value obtained: -0.0254
# Current minimum: -0.0607
# Iteration No: 24 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 13, 'alpha': 0.8192249010982993, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.10 sec. Users per second: 1378
# SearchBayesianSkopt: Config 23 is suboptimal. Config: {'topK': 13, 'alpha': 0.8192249010982993, 'normalize_similarity': False} - results: ROC_AUC: 0.0831260, PRECISION: 0.0156267, PRECISION_RECALL_MIN_DEN: 0.0576125, RECALL: 0.0562408, MAP: 0.0276670, MRR: 0.0585777, NDCG: 0.0414571, F1: 0.0244577, HIT_RATE: 0.1562666, ARHR: 0.0641349, NOVELTY: 0.0055455, AVERAGE_POPULARITY: 0.0215435, DIVERSITY_MEAN_INTER_LIST: 0.9906691, DIVERSITY_HERFINDAHL: 0.9990494, COVERAGE_ITEM: 0.5630799, COVERAGE_ITEM_CORRECT: 0.0305294, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.0924877, DIVERSITY_GINI: 0.3013915, SHANNON_ENTROPY: 12.9269655,
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 23.4493
# Function value obtained: -0.0277
# Current minimum: -0.0607
# Iteration No: 25 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 8, 'alpha': 0.24863216587559792, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.48 sec. Users per second: 1261
# SearchBayesianSkopt: Config 24 is suboptimal. Config: {'topK': 8, 'alpha': 0.24863216587559792, 'normalize_similarity': False} - results: ROC_AUC: 0.1450201, PRECISION: 0.0287432, PRECISION_RECALL_MIN_DEN: 0.0993868, RECALL: 0.0962211, MAP: 0.0482430, MRR: 0.1071937, NDCG: 0.0724570, F1: 0.0442638, HIT_RATE: 0.2874315, ARHR: 0.1207859, NOVELTY: 0.0049839, AVERAGE_POPULARITY: 0.0901337, DIVERSITY_MEAN_INTER_LIST: 0.9730739, DIVERSITY_HERFINDAHL: 0.9972902, COVERAGE_ITEM: 0.4145910, COVERAGE_ITEM_CORRECT: 0.0309143, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1593054, DIVERSITY_GINI: 0.1236381, SHANNON_ENTROPY: 11.0516346,
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 23.8567
# Function value obtained: -0.0482
# Current minimum: -0.0607
# Iteration No: 26 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 69, 'alpha': 0.4341045781628378, 'normalize_similarity': True}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.53 sec. Users per second: 1249
# SearchBayesianSkopt: Config 25 is suboptimal. Config: {'topK': 69, 'alpha': 0.4341045781628378, 'normalize_similarity': True} - results: ROC_AUC: 0.1604119, PRECISION: 0.0336221, PRECISION_RECALL_MIN_DEN: 0.1113274, RECALL: 0.1071498, MAP: 0.0527650, MRR: 0.1203977, NDCG: 0.0799656, F1: 0.0511835, HIT_RATE: 0.3362206, ARHR: 0.1390384, NOVELTY: 0.0051356, AVERAGE_POPULARITY: 0.0624454, DIVERSITY_MEAN_INTER_LIST: 0.9945601, DIVERSITY_HERFINDAHL: 0.9994384, COVERAGE_ITEM: 0.5086814, COVERAGE_ITEM_CORRECT: 0.0459288, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1756638, DIVERSITY_GINI: 0.2091494, SHANNON_ENTROPY: 12.4432481,
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 26.0676
# Function value obtained: -0.0528
# Current minimum: -0.0607
# Iteration No: 27 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 1000, 'alpha': 0.1740777630703834, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.63 sec. Users per second: 1005
# SearchBayesianSkopt: Config 26 is suboptimal. Config: {'topK': 1000, 'alpha': 0.1740777630703834, 'normalize_similarity': False} - results: ROC_AUC: 0.1571541, PRECISION: 0.0325614, PRECISION_RECALL_MIN_DEN: 0.1141264, RECALL: 0.1106035, MAP: 0.0538924, MRR: 0.1166434, NDCG: 0.0811151, F1: 0.0503113, HIT_RATE: 0.3256143, ARHR: 0.1333327, NOVELTY: 0.0046173, AVERAGE_POPULARITY: 0.1481611, DIVERSITY_MEAN_INTER_LIST: 0.9678891, DIVERSITY_HERFINDAHL: 0.9967718, COVERAGE_ITEM: 0.3270452, COVERAGE_ITEM_CORRECT: 0.0312608, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1752863, DIVERSITY_GINI: 0.0765311, SHANNON_ENTROPY: 10.3532844,
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 37.0888
# Function value obtained: -0.0539
# Current minimum: -0.0607
# Iteration No: 28 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 999, 'alpha': 0.7204051639248087, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 6.03 sec. Users per second: 938
# SearchBayesianSkopt: Config 27 is suboptimal. Config: {'topK': 999, 'alpha': 0.7204051639248087, 'normalize_similarity': False} - results: ROC_AUC: 0.1700706, PRECISION: 0.0364504, PRECISION_RECALL_MIN_DEN: 0.1200613, RECALL: 0.1157076, MAP: 0.0575535, MRR: 0.1276241, NDCG: 0.0867121, F1: 0.0554370, HIT_RATE: 0.3645042, ARHR: 0.1489329, NOVELTY: 0.0049417, AVERAGE_POPULARITY: 0.0971635, DIVERSITY_MEAN_INTER_LIST: 0.9875651, DIVERSITY_HERFINDAHL: 0.9987391, COVERAGE_ITEM: 0.4590183, COVERAGE_ITEM_CORRECT: 0.0399230, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1873663, DIVERSITY_GINI: 0.1600996, SHANNON_ENTROPY: 11.7347172,
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 36.5973
# Function value obtained: -0.0576
# Current minimum: -0.0607
# Iteration No: 29 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 1000, 'alpha': 1.7820678865352004, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.68 sec. Users per second: 1209
# SearchBayesianSkopt: Config 28 is suboptimal. Config: {'topK': 1000, 'alpha': 1.7820678865352004, 'normalize_similarity': False} - results: ROC_AUC: 0.0859526, PRECISION: 0.0180131, PRECISION_RECALL_MIN_DEN: 0.0723764, RECALL: 0.0711208, MAP: 0.0285450, MRR: 0.0573363, NDCG: 0.0457630, F1: 0.0287456, HIT_RATE: 0.1801308, ARHR: 0.0628692, NOVELTY: 0.0053036, AVERAGE_POPULARITY: 0.0484703, DIVERSITY_MEAN_INTER_LIST: 0.9966742, DIVERSITY_HERFINDAHL: 0.9996498, COVERAGE_ITEM: 0.5123388, COVERAGE_ITEM_CORRECT: 0.0309143, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1065811, DIVERSITY_GINI: 0.2511548, SHANNON_ENTROPY: 12.8611297,
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 37.6252
# Function value obtained: -0.0285
# Current minimum: -0.0607
# Iteration No: 30 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 994, 'alpha': 0.8999001115298566, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.83 sec. Users per second: 970
# SearchBayesianSkopt: Config 29 is suboptimal. Config: {'topK': 994, 'alpha': 0.8999001115298566, 'normalize_similarity': False} - results: ROC_AUC: 0.1549096, PRECISION: 0.0338519, PRECISION_RECALL_MIN_DEN: 0.1115607, RECALL: 0.1073135, MAP: 0.0512722, MRR: 0.1140047, NDCG: 0.0783499, F1: 0.0514682, HIT_RATE: 0.3385186, ARHR: 0.1338620, NOVELTY: 0.0050667, AVERAGE_POPULARITY: 0.0797464, DIVERSITY_MEAN_INTER_LIST: 0.9918119, DIVERSITY_HERFINDAHL: 0.9991637, COVERAGE_ITEM: 0.4828489, COVERAGE_ITEM_CORRECT: 0.0400000, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1745313, DIVERSITY_GINI: 0.1922665, SHANNON_ENTROPY: 12.1794630,
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 38.3272
# Function value obtained: -0.0513
# Current minimum: -0.0607
# Iteration No: 31 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 543, 'alpha': 0.12879283507746456, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.81 sec. Users per second: 974
# SearchBayesianSkopt: Config 30 is suboptimal. Config: {'topK': 543, 'alpha': 0.12879283507746456, 'normalize_similarity': False} - results: ROC_AUC: 0.1550654, PRECISION: 0.0321725, PRECISION_RECALL_MIN_DEN: 0.1114668, RECALL: 0.1079989, MAP: 0.0522551, MRR: 0.1146435, NDCG: 0.0791775, F1: 0.0495764, HIT_RATE: 0.3217253, ARHR: 0.1310301, NOVELTY: 0.0046407, AVERAGE_POPULARITY: 0.1437938, DIVERSITY_MEAN_INTER_LIST: 0.9696386, DIVERSITY_HERFINDAHL: 0.9969467, COVERAGE_ITEM: 0.3381713, COVERAGE_ITEM_CORRECT: 0.0314533, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1737763, DIVERSITY_GINI: 0.0815887, SHANNON_ENTROPY: 10.4626671,
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 35.6988
# Function value obtained: -0.0523
# Current minimum: -0.0607
# Iteration No: 32 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 544, 'alpha': 0.3331621114264762, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.04 sec. Users per second: 1401
# SearchBayesianSkopt: Config 31 is suboptimal. Config: {'topK': 544, 'alpha': 0.3331621114264762, 'normalize_similarity': False} - results: ROC_AUC: 0.1682002, PRECISION: 0.0359908, PRECISION_RECALL_MIN_DEN: 0.1230303, RECALL: 0.1191146, MAP: 0.0579920, MRR: 0.1258460, NDCG: 0.0875816, F1: 0.0552789, HIT_RATE: 0.3599081, ARHR: 0.1447837, NOVELTY: 0.0047167, AVERAGE_POPULARITY: 0.1285565, DIVERSITY_MEAN_INTER_LIST: 0.9770165, DIVERSITY_HERFINDAHL: 0.9976844, COVERAGE_ITEM: 0.3706641, COVERAGE_ITEM_CORRECT: 0.0369586, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1898830, DIVERSITY_GINI: 0.0985630, SHANNON_ENTROPY: 10.8263246,
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 32.2572
# Function value obtained: -0.0580
# Current minimum: -0.0607
# Iteration No: 33 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 998, 'alpha': 0.5097085983673882, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.83 sec. Users per second: 971
# SearchBayesianSkopt: Config 32 is suboptimal. Config: {'topK': 998, 'alpha': 0.5097085983673882, 'normalize_similarity': False} - results: ROC_AUC: 0.1735063, PRECISION: 0.0371752, PRECISION_RECALL_MIN_DEN: 0.1251287, RECALL: 0.1210747, MAP: 0.0591740, MRR: 0.1297743, NDCG: 0.0895694, F1: 0.0568844, HIT_RATE: 0.3717518, ARHR: 0.1500156, NOVELTY: 0.0047847, AVERAGE_POPULARITY: 0.1197338, DIVERSITY_MEAN_INTER_LIST: 0.9804392, DIVERSITY_HERFINDAHL: 0.9980266, COVERAGE_ITEM: 0.4057363, COVERAGE_ITEM_CORRECT: 0.0391530, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1937838, DIVERSITY_GINI: 0.1183714, SHANNON_ENTROPY: 11.1128240,
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 37.1901
# Function value obtained: -0.0592
# Current minimum: -0.0607
# Iteration No: 34 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 312, 'alpha': 0.44473319197468814, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 5.26 sec. Users per second: 1076
# SearchBayesianSkopt: Config 33 is suboptimal. Config: {'topK': 312, 'alpha': 0.44473319197468814, 'normalize_similarity': False} - results: ROC_AUC: 0.1725388, PRECISION: 0.0370161, PRECISION_RECALL_MIN_DEN: 0.1248558, RECALL: 0.1207006, MAP: 0.0603632, MRR: 0.1306742, NDCG: 0.0901977, F1: 0.0566568, HIT_RATE: 0.3701609, ARHR: 0.1516165, NOVELTY: 0.0048216, AVERAGE_POPULARITY: 0.1107696, DIVERSITY_MEAN_INTER_LIST: 0.9834201, DIVERSITY_HERFINDAHL: 0.9983246, COVERAGE_ITEM: 0.4128200, COVERAGE_ITEM_CORRECT: 0.0403850, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1915188, DIVERSITY_GINI: 0.1242295, SHANNON_ENTROPY: 11.2789137,
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 30.9349
# Function value obtained: -0.0604
# Current minimum: -0.0607
# Iteration No: 35 started. Searching for the next optimal point.
# P3alphaRecommender: URM Detected 82 (1.03 %) cold users.
# P3alphaRecommender: URM Detected 2372 (9.13 %) cold items.
# SearchBayesianSkopt: Testing config: {'topK': 5, 'alpha': 0.5434307872167726, 'normalize_similarity': False}
# EvaluatorHoldout: Processed 5657 ( 100.00% ) in 4.17 sec. Users per second: 1355
# SearchBayesianSkopt: Config 34 is suboptimal. Config: {'topK': 5, 'alpha': 0.5434307872167726, 'normalize_similarity': False} - results: ROC_AUC: 0.1122067, PRECISION: 0.0194449, PRECISION_RECALL_MIN_DEN: 0.0612156, RECALL: 0.0588086, MAP: 0.0349826, MRR: 0.0826200, NDCG: 0.0504882, F1: 0.0292263, HIT_RATE: 0.1944494, ARHR: 0.0918601, NOVELTY: 0.0054751, AVERAGE_POPULARITY: 0.0382886, DIVERSITY_MEAN_INTER_LIST: 0.8730401, DIVERSITY_HERFINDAHL: 0.9872886, COVERAGE_ITEM: 0.4222137, COVERAGE_ITEM_CORRECT: 0.0274110, COVERAGE_USER: 0.7118409, COVERAGE_USER_CORRECT: 0.1090978, DIVERSITY_GINI: 0.1392590, SHANNON_ENTROPY: 10.1940089,
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 24.1139
# Function value obtained: -0.0350
# Current minimum: -0.0607
# SearchBayesianSkopt: Search complete. Best config is 21: {'topK': 267, 'alpha': 0.4079116116383131, 'normalize_similarity': False}
